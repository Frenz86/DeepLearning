# %% [markdown]
# #  Saving and Loading a Keras Neural Network
#
# Complex neural networks will take a long time to fit/train.  It is helpful to be able to save these neural networks so that they can be reloaded later.  A reloaded neural network will not require retraining.  Keras provides three formats for neural network saving.
#
# * **JSON** - Stores the neural network structure (no weights) in the [JSON file format](https://en.wikipedia.org/wiki/JSON).
# * **HDF5** - Stores the complete neural network (with weights) in the [HDF5 file format](https://en.wikipedia.org/wiki/Hierarchical_Data_Format). Do not confuse HDF5 with [HDFS]

# %%
# !wget https://data.heatonresearch.com/data/t81-558/auto-mpg.csv
# Out:
# --2024-01-24 22:18:22--  https://data.heatonresearch.com/data/t81-558/auto-mpg.csv
# Resolving data.heatonresearch.com (data.heatonresearch.com)... 18.160.143.5, 18.160.143.41, 18.160.143.31, ...
# Connecting to data.heatonresearch.com (data.heatonresearch.com)|18.160.143.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18121 (18K) [text/csv]
# Saving to: ‘auto-mpg.csv.1’
#
# auto-mpg.csv.1      100%[===================>]  17.70K  --.-KB/s    in 0.001s
#
# 2024-01-24 22:18:22 (14.2 MB/s) - ‘auto-mpg.csv.1’ saved [18121/18121]

# %%
import pandas as pd
import os
import requests
import numpy as np
from sklearn import metrics

df = pd.read_csv('auto-mpg.csv', na_values=['NA', '?'])
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 393  27.0          4         140.0        86.0    2790          15.6    82
# 394  44.0          4          97.0        52.0    2130          24.6    82
# 395  32.0          4         135.0        84.0    2295          11.6    82
# 396  28.0          4         120.0        79.0    2625          18.6    82
# 397  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 393       1            ford mustang gl
# 394       2                  vw pickup
# 395       1              dodge rampage
# 396       1                ford ranger
# 397       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())

# Pandas to Numpy
X = df[['cylinders', 'displacement', 'horsepower', 'weight','acceleration', 'year', 'origin']].values
y = df['mpg'].values # regression

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Step 3: Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled,y,
                                                    test_size=0.2,
                                                    random_state=667
                                                    )

# %%
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.layers import Dense, Activation

# Build the neural network
model = Sequential()
model.add(Dense(25, input_dim=X.shape[1], activation='relu')) # Hidden 1
model.add(Dense(10, activation='relu')) # Hidden 2
model.add(Dense(1)) # Output

model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 25)                200
#
#  dense_10 (Dense)            (None, 10)                260
#
#  dense_11 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 471 (1.84 KB)
# Trainable params: 471 (1.84 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train,y_train,
          verbose=2,
          epochs=100
          )
# Out:
# Epoch 1/100
# 10/10 - 1s - loss: 613.3707 - 975ms/epoch - 98ms/step
# Epoch 2/100
# 10/10 - 0s - loss: 604.9064 - 22ms/epoch - 2ms/step
# Epoch 3/100
# 10/10 - 0s - loss: 595.7247 - 18ms/epoch - 2ms/step
# Epoch 4/100
# 10/10 - 0s - loss: 585.7385 - 19ms/epoch - 2ms/step
# Epoch 5/100
# 10/10 - 0s - loss: 574.5911 - 20ms/epoch - 2ms/step
# Epoch 6/100
# 10/10 - 0s - loss: 562.1229 - 22ms/epoch - 2ms/step
# Epoch 7/100
# 10/10 - 0s - loss: 548.0933 - 21ms/epoch - 2ms/step
# Epoch 8/100
# 10/10 - 0s - loss: 531.9626 - 21ms/epoch - 2ms/step
# Epoch 9/100
# 10/10 - 0s - loss: 514.3755 - 20ms/epoch - 2ms/step
# Epoch 10/100
# 10/10 - 0s - loss: 494.9157 - 20ms/epoch - 2ms/step
# Epoch 11/100
# 10/10 - 0s - loss: 473.2151 - 20ms/epoch - 2ms/step
# Epoch 12/100
# 10/10 - 0s - loss: 449.8073 - 20ms/epoch - 2ms/step
# Epoch 13/100
# 10/10 - 0s - loss: 424.8353 - 20ms/epoch - 2ms/step
# Epoch 14/100
# 10/10 - 0s - loss: 398.5667 - 23ms/epoch - 2ms/step
# Epoch 15/100
# 10/10 - 0s - loss: 370.4925 - 21ms/epoch - 2ms/step
# Epoch 16/100
# 10/10 - 0s - loss: 342.4806 - 20ms/epoch - 2ms/step
# Epoch 17/100
# 10/10 - 0s - loss: 313.0397 - 20ms/epoch - 2ms/step
# Epoch 18/100
# 10/10 - 0s - loss: 284.6219 - 19ms/epoch - 2ms/step
# Epoch 19/100
# 10/10 - 0s - loss: 256.2966 - 22ms/epoch - 2ms/step
# Epoch 20/100
# 10/10 - 0s - loss: 228.8394 - 19ms/epoch - 2ms/step
# Epoch 21/100
# 10/10 - 0s - loss: 204.2853 - 22ms/epoch - 2ms/step
# Epoch 22/100
# 10/10 - 0s - loss: 180.7492 - 21ms/epoch - 2ms/step
# Epoch 23/100
# 10/10 - 0s - loss: 160.5373 - 20ms/epoch - 2ms/step
# Epoch 24/100
# 10/10 - 0s - loss: 142.4970 - 20ms/epoch - 2ms/step
# Epoch 25/100
# 10/10 - 0s - loss: 128.2917 - 20ms/epoch - 2ms/step
# Epoch 26/100
# 10/10 - 0s - loss: 115.8981 - 21ms/epoch - 2ms/step
# Epoch 27/100
# 10/10 - 0s - loss: 106.4089 - 21ms/epoch - 2ms/step
# Epoch 28/100
# 10/10 - 0s - loss: 98.8004 - 21ms/epoch - 2ms/step
# Epoch 29/100
# 10/10 - 0s - loss: 92.9634 - 22ms/epoch - 2ms/step
# Epoch 30/100
# 10/10 - 0s - loss: 87.8302 - 21ms/epoch - 2ms/step
# Epoch 31/100
# 10/10 - 0s - loss: 83.8335 - 22ms/epoch - 2ms/step
# Epoch 32/100
# 10/10 - 0s - loss: 80.2540 - 25ms/epoch - 2ms/step
# Epoch 33/100
# 10/10 - 0s - loss: 76.8613 - 22ms/epoch - 2ms/step
# Epoch 34/100
# 10/10 - 0s - loss: 73.8957 - 24ms/epoch - 2ms/step
# Epoch 35/100
# 10/10 - 0s - loss: 71.0193 - 21ms/epoch - 2ms/step
# Epoch 36/100
# 10/10 - 0s - loss: 68.2860 - 22ms/epoch - 2ms/step
# Epoch 37/100
# 10/10 - 0s - loss: 65.5796 - 21ms/epoch - 2ms/step
# Epoch 38/100
# 10/10 - 0s - loss: 63.0542 - 22ms/epoch - 2ms/step
# Epoch 39/100
# 10/10 - 0s - loss: 60.7036 - 28ms/epoch - 3ms/step
# Epoch 40/100
# 10/10 - 0s - loss: 58.2246 - 22ms/epoch - 2ms/step
# Epoch 41/100
# 10/10 - 0s - loss: 55.9938 - 23ms/epoch - 2ms/step
# Epoch 42/100
# 10/10 - 0s - loss: 53.7622 - 20ms/epoch - 2ms/step
# Epoch 43/100
# 10/10 - 0s - loss: 51.7339 - 21ms/epoch - 2ms/step
# Epoch 44/100
# 10/10 - 0s - loss: 49.7408 - 20ms/epoch - 2ms/step
# Epoch 45/100
# 10/10 - 0s - loss: 47.8764 - 22ms/epoch - 2ms/step
# Epoch 46/100
# 10/10 - 0s - loss: 46.1352 - 21ms/epoch - 2ms/step
# Epoch 47/100
# 10/10 - 0s - loss: 44.4374 - 26ms/epoch - 3ms/step
# Epoch 48/100
# 10/10 - 0s - loss: 42.8204 - 19ms/epoch - 2ms/step
# Epoch 49/100
# 10/10 - 0s - loss: 41.3705 - 20ms/epoch - 2ms/step
# Epoch 50/100
# 10/10 - 0s - loss: 39.9693 - 20ms/epoch - 2ms/step
# Epoch 51/100
# 10/10 - 0s - loss: 38.6098 - 20ms/epoch - 2ms/step
# Epoch 52/100
# 10/10 - 0s - loss: 37.4409 - 21ms/epoch - 2ms/step
# Epoch 53/100
# 10/10 - 0s - loss: 36.2633 - 19ms/epoch - 2ms/step
# Epoch 54/100
# 10/10 - 0s - loss: 35.2343 - 20ms/epoch - 2ms/step
# Epoch 55/100
# 10/10 - 0s - loss: 34.2117 - 19ms/epoch - 2ms/step
# Epoch 56/100
# 10/10 - 0s - loss: 33.3083 - 23ms/epoch - 2ms/step
# Epoch 57/100
# 10/10 - 0s - loss: 32.4748 - 19ms/epoch - 2ms/step
# Epoch 58/100
# 10/10 - 0s - loss: 31.6678 - 21ms/epoch - 2ms/step
# Epoch 59/100
# 10/10 - 0s - loss: 30.9767 - 25ms/epoch - 3ms/step
# Epoch 60/100
# 10/10 - 0s - loss: 30.3125 - 27ms/epoch - 3ms/step
# Epoch 61/100
# 10/10 - 0s - loss: 29.7268 - 21ms/epoch - 2ms/step
# Epoch 62/100
# 10/10 - 0s - loss: 29.1592 - 19ms/epoch - 2ms/step
# Epoch 63/100
# 10/10 - 0s - loss: 28.6417 - 19ms/epoch - 2ms/step
# Epoch 64/100
# 10/10 - 0s - loss: 28.2002 - 21ms/epoch - 2ms/step
# Epoch 65/100
# 10/10 - 0s - loss: 27.7898 - 20ms/epoch - 2ms/step
# Epoch 66/100
# 10/10 - 0s - loss: 27.3722 - 21ms/epoch - 2ms/step
# Epoch 67/100
# 10/10 - 0s - loss: 27.0110 - 21ms/epoch - 2ms/step
# Epoch 68/100
# 10/10 - 0s - loss: 26.6939 - 22ms/epoch - 2ms/step
# Epoch 69/100
# 10/10 - 0s - loss: 26.3838 - 20ms/epoch - 2ms/step
# Epoch 70/100
# 10/10 - 0s - loss: 26.1232 - 21ms/epoch - 2ms/step
# Epoch 71/100
# 10/10 - 0s - loss: 25.8508 - 19ms/epoch - 2ms/step
# Epoch 72/100
# 10/10 - 0s - loss: 25.6383 - 19ms/epoch - 2ms/step
# Epoch 73/100
# 10/10 - 0s - loss: 25.3892 - 19ms/epoch - 2ms/step
# Epoch 74/100
# 10/10 - 0s - loss: 25.1920 - 19ms/epoch - 2ms/step
# Epoch 75/100
# 10/10 - 0s - loss: 24.9951 - 25ms/epoch - 2ms/step
# Epoch 76/100
# 10/10 - 0s - loss: 24.8399 - 23ms/epoch - 2ms/step
# Epoch 77/100
# 10/10 - 0s - loss: 24.6175 - 20ms/epoch - 2ms/step
# Epoch 78/100
# 10/10 - 0s - loss: 24.4719 - 24ms/epoch - 2ms/step
# Epoch 79/100
# 10/10 - 0s - loss: 24.3027 - 20ms/epoch - 2ms/step
# Epoch 80/100
# 10/10 - 0s - loss: 24.1620 - 24ms/epoch - 2ms/step
# Epoch 81/100
# 10/10 - 0s - loss: 24.0062 - 33ms/epoch - 3ms/step
# Epoch 82/100
# 10/10 - 0s - loss: 23.8703 - 21ms/epoch - 2ms/step
# Epoch 83/100
# 10/10 - 0s - loss: 23.7369 - 20ms/epoch - 2ms/step
# Epoch 84/100
# 10/10 - 0s - loss: 23.6030 - 18ms/epoch - 2ms/step
# Epoch 85/100
# 10/10 - 0s - loss: 23.4674 - 20ms/epoch - 2ms/step
# Epoch 86/100
# 10/10 - 0s - loss: 23.3413 - 20ms/epoch - 2ms/step
# Epoch 87/100
# 10/10 - 0s - loss: 23.2271 - 24ms/epoch - 2ms/step
# Epoch 88/100
# 10/10 - 0s - loss: 23.0914 - 21ms/epoch - 2ms/step
# Epoch 89/100
# 10/10 - 0s - loss: 22.9725 - 21ms/epoch - 2ms/step
# Epoch 90/100
# 10/10 - 0s - loss: 22.8528 - 20ms/epoch - 2ms/step
# Epoch 91/100
# 10/10 - 0s - loss: 22.7405 - 21ms/epoch - 2ms/step
# Epoch 92/100
# 10/10 - 0s - loss: 22.6268 - 22ms/epoch - 2ms/step
# Epoch 93/100
# 10/10 - 0s - loss: 22.4901 - 21ms/epoch - 2ms/step
# Epoch 94/100
# 10/10 - 0s - loss: 22.3852 - 21ms/epoch - 2ms/step
# Epoch 95/100
# 10/10 - 0s - loss: 22.2654 - 20ms/epoch - 2ms/step
# Epoch 96/100
# 10/10 - 0s - loss: 22.1564 - 23ms/epoch - 2ms/step
# Epoch 97/100
# 10/10 - 0s - loss: 22.0477 - 22ms/epoch - 2ms/step
# Epoch 98/100
# 10/10 - 0s - loss: 21.9310 - 20ms/epoch - 2ms/step
# Epoch 99/100
# 10/10 - 0s - loss: 21.8197 - 25ms/epoch - 2ms/step
# Epoch 100/100
# 10/10 - 0s - loss: 21.7221 - 18ms/epoch - 2ms/step

# %%
loss = model.evaluate(X_test, y_test, verbose=1)
print(f'Mean Squared Error on Test Data: {loss}')

y_pred = model.predict(X_test)

# Measure RMSE error.  RMSE is common for regression.
score = np.sqrt(metrics.mean_squared_error(y_pred,y_test))
print(f"Before save score (RMSE): {score}")

save_path = "."
# save neural network structure to JSON (no weights)
model_json = model.to_json()
with open(os.path.join(save_path,"network.json"), "w") as json_file:
    json_file.write(model_json)

# save entire network to HDF5 (save everything, suggested)
model.save(os.path.join(save_path,"network.h5"))
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 25.3988
# Mean Squared Error on Test Data: 25.39881706237793
# 3/3 [==============================] - 0s 4ms/step
# Before save score (RMSE): 5.039723914732977
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# The code below sets up a neural network and reads the data (for predictions), but it does not clear the model directory or fit the neural network.  The weights from the previous fit are used.

# %% [markdown]
# Now we reload the network and perform another prediction.  The RMSE should match the previous one exactly if the neural network was really saved and reloaded.

# %%
model2 = load_model(os.path.join(save_path,"network.h5"))
pred = model2.predict(X_test)

# Measure RMSE error.  RMSE is common for regression.
score = np.sqrt(metrics.mean_squared_error(pred,y_test))
print(f"After load score (RMSE): {score}")
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7d1b75ccf2e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 4ms/step
# After load score (RMSE): 4.000932803113682
