# %% [markdown]
# #  Early Stopping in Keras to Prevent Overfitting

# %% [markdown]
# **Overfitting** occurs when a neural network is trained to the point that it begins to memorize rather than generalize.
#
# ![Training vs Validation Error for Overfitting](https://raw.githubusercontent.com/jeffheaton/t81_558_deep_learning/master/images/class_3_training_val.png "Training vs Validation Error for Overfitting")
#
# It is important to segment the original dataset into several datasets:
#
# * **Training Set**
# * **Validation Set**
# * **Holdout Set**
#
# There are several different ways that these sets can be constructed.  The following programs demonstrate some of these.
#
# The first method is a training and validation set.  The training data are used to train the neural network until the validation set no longer improves.  This attempts to stop at a near optimal training point.  This method will only give accurate "out of sample" predictions for the validation set, this is usually 20% or so of the data.  The predictions for the training data will be overly optimistic, as these were the data that the neural network was trained on.
#
# ![Training with a Validation Set](https://raw.githubusercontent.com/jeffheaton/t81_558_deep_learning/master/images/class_1_train_val.png "Training with a Validation Set")

# %% [markdown]
# ### Early Stopping with Classification

# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.model_selection import train_test_split

df = pd.read_csv("https://data.heatonresearch.com/data/t81-558/iris.csv")
df
# Out:
#      sepal_l  sepal_w  petal_l  petal_w         species
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 3        4.6      3.1      1.5      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 146      6.3      2.5      5.0      1.9  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
X = df[['sepal_l', 'sepal_w', 'petal_l', 'petal_w']].values
dummies = pd.get_dummies(df['species']) # Classification
species = dummies.columns
y = dummies.values

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.25,
                                                    random_state=667
                                                    )

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential()
model.add(Dense(50, input_dim=X.shape[1], activation='relu')) # Hidden 1
model.add(Dense(25, activation='relu')) # Hidden 2
model.add(Dense(y.shape[1],activation='softmax')) # Output

model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_17 (Dense)            (None, 50)                250
#
#  dense_18 (Dense)            (None, 25)                1275
#
#  dense_19 (Dense)            (None, 3)                 78
#
# =================================================================
# Total params: 1603 (6.26 KB)
# Trainable params: 1603 (6.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
monitor = EarlyStopping(monitor='val_loss',
                        min_delta=1e-3,
                        patience=5,
                        verbose=1,
                        mode='auto',
                        restore_best_weights=True)

model.fit(X_train,y_train,
          validation_data=(X_test,y_test),
          callbacks=[monitor],
          verbose=2,
          epochs=1000
          )
# Out:
# Epoch 1/1000
# 4/4 - 1s - loss: 0.8706 - val_loss: 0.7900 - 1s/epoch - 298ms/step
# Epoch 2/1000
# 4/4 - 0s - loss: 0.7671 - val_loss: 0.7384 - 58ms/epoch - 15ms/step
# Epoch 3/1000
# 4/4 - 0s - loss: 0.7084 - val_loss: 0.6832 - 55ms/epoch - 14ms/step
# Epoch 4/1000
# 4/4 - 0s - loss: 0.6589 - val_loss: 0.6295 - 55ms/epoch - 14ms/step
# Epoch 5/1000
# 4/4 - 0s - loss: 0.6152 - val_loss: 0.5936 - 55ms/epoch - 14ms/step
# Epoch 6/1000
# 4/4 - 0s - loss: 0.5866 - val_loss: 0.5792 - 39ms/epoch - 10ms/step
# Epoch 7/1000
# 4/4 - 0s - loss: 0.5682 - val_loss: 0.5650 - 58ms/epoch - 15ms/step
# Epoch 8/1000
# 4/4 - 0s - loss: 0.5490 - val_loss: 0.5481 - 56ms/epoch - 14ms/step
# Epoch 9/1000
# 4/4 - 0s - loss: 0.5306 - val_loss: 0.5236 - 57ms/epoch - 14ms/step
# Epoch 10/1000
# 4/4 - 0s - loss: 0.5160 - val_loss: 0.5020 - 39ms/epoch - 10ms/step
# Epoch 11/1000
# 4/4 - 0s - loss: 0.5043 - val_loss: 0.4882 - 57ms/epoch - 14ms/step
# Epoch 12/1000
# 4/4 - 0s - loss: 0.4869 - val_loss: 0.4864 - 40ms/epoch - 10ms/step
# Epoch 13/1000
# 4/4 - 0s - loss: 0.4788 - val_loss: 0.4854 - 45ms/epoch - 11ms/step
# Epoch 14/1000
# 4/4 - 0s - loss: 0.4640 - val_loss: 0.4594 - 56ms/epoch - 14ms/step
# Epoch 15/1000
# 4/4 - 0s - loss: 0.4499 - val_loss: 0.4430 - 58ms/epoch - 15ms/step
# Epoch 16/1000
# 4/4 - 0s - loss: 0.4505 - val_loss: 0.4281 - 61ms/epoch - 15ms/step
# Epoch 17/1000
# 4/4 - 0s - loss: 0.4368 - val_loss: 0.4403 - 40ms/epoch - 10ms/step
# Epoch 18/1000
# 4/4 - 0s - loss: 0.4222 - val_loss: 0.4297 - 37ms/epoch - 9ms/step
# Epoch 19/1000
# 4/4 - 0s - loss: 0.4129 - val_loss: 0.4182 - 59ms/epoch - 15ms/step
# Epoch 20/1000
# 4/4 - 0s - loss: 0.4023 - val_loss: 0.4015 - 61ms/epoch - 15ms/step
# Epoch 21/1000
# 4/4 - 0s - loss: 0.3932 - val_loss: 0.3854 - 56ms/epoch - 14ms/step
# Epoch 22/1000
# 4/4 - 0s - loss: 0.3872 - val_loss: 0.3780 - 58ms/epoch - 15ms/step
# Epoch 23/1000
# 4/4 - 0s - loss: 0.3789 - val_loss: 0.3784 - 54ms/epoch - 14ms/step
# Epoch 24/1000
# 4/4 - 0s - loss: 0.3697 - val_loss: 0.3752 - 40ms/epoch - 10ms/step
# Epoch 25/1000
# 4/4 - 0s - loss: 0.3630 - val_loss: 0.3648 - 60ms/epoch - 15ms/step
# Epoch 26/1000
# 4/4 - 0s - loss: 0.3564 - val_loss: 0.3552 - 42ms/epoch - 10ms/step
# Epoch 27/1000
# 4/4 - 0s - loss: 0.3467 - val_loss: 0.3578 - 54ms/epoch - 13ms/step
# Epoch 28/1000
# 4/4 - 0s - loss: 0.3431 - val_loss: 0.3555 - 37ms/epoch - 9ms/step
# Epoch 29/1000
# 4/4 - 0s - loss: 0.3354 - val_loss: 0.3339 - 62ms/epoch - 15ms/step
# Epoch 30/1000
# 4/4 - 0s - loss: 0.3275 - val_loss: 0.3234 - 57ms/epoch - 14ms/step
# Epoch 31/1000
# 4/4 - 0s - loss: 0.3225 - val_loss: 0.3252 - 56ms/epoch - 14ms/step
# Epoch 32/1000
# 4/4 - 0s - loss: 0.3149 - val_loss: 0.3127 - 56ms/epoch - 14ms/step
# Epoch 33/1000
# 4/4 - 0s - loss: 0.3078 - val_loss: 0.3158 - 38ms/epoch - 10ms/step
# Epoch 34/1000
# 4/4 - 0s - loss: 0.3013 - val_loss: 0.3060 - 42ms/epoch - 10ms/step
# Epoch 35/1000
# 4/4 - 0s - loss: 0.2936 - val_loss: 0.3007 - 41ms/epoch - 10ms/step
# Epoch 36/1000
# 4/4 - 0s - loss: 0.2877 - val_loss: 0.2937 - 58ms/epoch - 15ms/step
# Epoch 37/1000
# 4/4 - 0s - loss: 0.2826 - val_loss: 0.2811 - 38ms/epoch - 10ms/step
# Epoch 38/1000
# 4/4 - 0s - loss: 0.2758 - val_loss: 0.2779 - 39ms/epoch - 10ms/step
# Epoch 39/1000
# 4/4 - 0s - loss: 0.2701 - val_loss: 0.2774 - 49ms/epoch - 12ms/step
# Epoch 40/1000
# 4/4 - 0s - loss: 0.2660 - val_loss: 0.2706 - 38ms/epoch - 9ms/step
# Epoch 41/1000
# 4/4 - 0s - loss: 0.2586 - val_loss: 0.2660 - 61ms/epoch - 15ms/step
# Epoch 42/1000
# 4/4 - 0s - loss: 0.2539 - val_loss: 0.2575 - 38ms/epoch - 9ms/step
# Epoch 43/1000
# 4/4 - 0s - loss: 0.2492 - val_loss: 0.2469 - 55ms/epoch - 14ms/step
# Epoch 44/1000
# 4/4 - 0s - loss: 0.2440 - val_loss: 0.2457 - 56ms/epoch - 14ms/step
# Epoch 45/1000
# 4/4 - 0s - loss: 0.2386 - val_loss: 0.2494 - 38ms/epoch - 9ms/step
# Epoch 46/1000
# 4/4 - 0s - loss: 0.2358 - val_loss: 0.2487 - 40ms/epoch - 10ms/step
# Epoch 47/1000
# 4/4 - 0s - loss: 0.2289 - val_loss: 0.2291 - 58ms/epoch - 15ms/step
# Epoch 48/1000
# 4/4 - 0s - loss: 0.2243 - val_loss: 0.2209 - 41ms/epoch - 10ms/step
# Epoch 49/1000
# 4/4 - 0s - loss: 0.2208 - val_loss: 0.2205 - 37ms/epoch - 9ms/step
# Epoch 50/1000
# 4/4 - 0s - loss: 0.2143 - val_loss: 0.2235 - 37ms/epoch - 9ms/step
# Epoch 51/1000
# 4/4 - 0s - loss: 0.2159 - val_loss: 0.2307 - 37ms/epoch - 9ms/step
# Epoch 52/1000
# 4/4 - 0s - loss: 0.2102 - val_loss: 0.2048 - 57ms/epoch - 14ms/step
# Epoch 53/1000
# 4/4 - 0s - loss: 0.2037 - val_loss: 0.1999 - 39ms/epoch - 10ms/step
# Epoch 54/1000
# 4/4 - 0s - loss: 0.1994 - val_loss: 0.2038 - 59ms/epoch - 15ms/step
# Epoch 55/1000
# 4/4 - 0s - loss: 0.1971 - val_loss: 0.2082 - 38ms/epoch - 9ms/step
# Epoch 56/1000
# 4/4 - 0s - loss: 0.1913 - val_loss: 0.1923 - 60ms/epoch - 15ms/step
# Epoch 57/1000
# 4/4 - 0s - loss: 0.1886 - val_loss: 0.1834 - 42ms/epoch - 10ms/step
# Epoch 58/1000
# 4/4 - 0s - loss: 0.1909 - val_loss: 0.1907 - 56ms/epoch - 14ms/step
# Epoch 59/1000
# 4/4 - 0s - loss: 0.1822 - val_loss: 0.1854 - 63ms/epoch - 16ms/step
# Epoch 60/1000
# 4/4 - 0s - loss: 0.1786 - val_loss: 0.1779 - 41ms/epoch - 10ms/step
# Epoch 61/1000
# 4/4 - 0s - loss: 0.1757 - val_loss: 0.1795 - 39ms/epoch - 10ms/step
# Epoch 62/1000
# 4/4 - 0s - loss: 0.1735 - val_loss: 0.1864 - 127ms/epoch - 32ms/step
# Epoch 63/1000
# 4/4 - 0s - loss: 0.1706 - val_loss: 0.1732 - 126ms/epoch - 31ms/step
# Epoch 64/1000
# 4/4 - 0s - loss: 0.1678 - val_loss: 0.1644 - 89ms/epoch - 22ms/step
# Epoch 65/1000
# 4/4 - 0s - loss: 0.1645 - val_loss: 0.1679 - 38ms/epoch - 10ms/step
# Epoch 66/1000
# 4/4 - 0s - loss: 0.1637 - val_loss: 0.1715 - 54ms/epoch - 13ms/step
# Epoch 67/1000
# 4/4 - 0s - loss: 0.1608 - val_loss: 0.1584 - 39ms/epoch - 10ms/step
# Epoch 68/1000
# 4/4 - 0s - loss: 0.1567 - val_loss: 0.1606 - 42ms/epoch - 10ms/step
# Epoch 69/1000
# 4/4 - 0s - loss: 0.1544 - val_loss: 0.1589 - 53ms/epoch - 13ms/step
# Epoch 70/1000
# 4/4 - 0s - loss: 0.1528 - val_loss: 0.1528 - 54ms/epoch - 13ms/step
# Epoch 71/1000
# 4/4 - 0s - loss: 0.1522 - val_loss: 0.1596 - 37ms/epoch - 9ms/step
# Epoch 72/1000
# 4/4 - 0s - loss: 0.1484 - val_loss: 0.1479 - 54ms/epoch - 14ms/step
# Epoch 73/1000
# 4/4 - 0s - loss: 0.1469 - val_loss: 0.1418 - 38ms/epoch - 9ms/step
# Epoch 74/1000
# 4/4 - 0s - loss: 0.1444 - val_loss: 0.1484 - 55ms/epoch - 14ms/step
# Epoch 75/1000
# 4/4 - 0s - loss: 0.1424 - val_loss: 0.1453 - 58ms/epoch - 14ms/step
# Epoch 76/1000
# 4/4 - 0s - loss: 0.1402 - val_loss: 0.1410 - 40ms/epoch - 10ms/step
# Epoch 77/1000
# 4/4 - 0s - loss: 0.1380 - val_loss: 0.1435 - 55ms/epoch - 14ms/step
# Epoch 78/1000
# 4/4 - 0s - loss: 0.1382 - val_loss: 0.1344 - 43ms/epoch - 11ms/step
# Epoch 79/1000
# 4/4 - 0s - loss: 0.1342 - val_loss: 0.1410 - 55ms/epoch - 14ms/step
# Epoch 80/1000
# 4/4 - 0s - loss: 0.1369 - val_loss: 0.1436 - 39ms/epoch - 10ms/step
# Epoch 81/1000
# 4/4 - 0s - loss: 0.1301 - val_loss: 0.1256 - 62ms/epoch - 16ms/step
# Epoch 82/1000
# 4/4 - 0s - loss: 0.1365 - val_loss: 0.1177 - 40ms/epoch - 10ms/step
# Epoch 83/1000
# 4/4 - 0s - loss: 0.1322 - val_loss: 0.1295 - 57ms/epoch - 14ms/step
# Epoch 84/1000
# 4/4 - 0s - loss: 0.1275 - val_loss: 0.1355 - 56ms/epoch - 14ms/step
# Epoch 85/1000
# 4/4 - 0s - loss: 0.1248 - val_loss: 0.1227 - 38ms/epoch - 10ms/step
# Epoch 86/1000
# 4/4 - 0s - loss: 0.1231 - val_loss: 0.1165 - 39ms/epoch - 10ms/step
# Epoch 87/1000
# 4/4 - 0s - loss: 0.1238 - val_loss: 0.1163 - 40ms/epoch - 10ms/step
# Epoch 88/1000
# 4/4 - 0s - loss: 0.1237 - val_loss: 0.1132 - 56ms/epoch - 14ms/step
# Epoch 89/1000
# 4/4 - 0s - loss: 0.1203 - val_loss: 0.1302 - 38ms/epoch - 9ms/step
# Epoch 90/1000
# 4/4 - 0s - loss: 0.1199 - val_loss: 0.1238 - 54ms/epoch - 14ms/step
# Epoch 91/1000
# 4/4 - 0s - loss: 0.1174 - val_loss: 0.1174 - 56ms/epoch - 14ms/step
# Epoch 92/1000
# 4/4 - 0s - loss: 0.1179 - val_loss: 0.1106 - 56ms/epoch - 14ms/step
# Epoch 93/1000
# 4/4 - 0s - loss: 0.1150 - val_loss: 0.1190 - 38ms/epoch - 10ms/step
# Epoch 94/1000
# 4/4 - 0s - loss: 0.1141 - val_loss: 0.1192 - 40ms/epoch - 10ms/step
# Epoch 95/1000
# 4/4 - 0s - loss: 0.1130 - val_loss: 0.1113 - 39ms/epoch - 10ms/step
# Epoch 96/1000
# 4/4 - 0s - loss: 0.1120 - val_loss: 0.1091 - 57ms/epoch - 14ms/step
# Epoch 97/1000
# 4/4 - 0s - loss: 0.1118 - val_loss: 0.1101 - 55ms/epoch - 14ms/step
# Epoch 98/1000
# 4/4 - 0s - loss: 0.1092 - val_loss: 0.1028 - 57ms/epoch - 14ms/step
# Epoch 99/1000
# 4/4 - 0s - loss: 0.1096 - val_loss: 0.1014 - 39ms/epoch - 10ms/step
# Epoch 100/1000
# 4/4 - 0s - loss: 0.1095 - val_loss: 0.1137 - 37ms/epoch - 9ms/step
# Epoch 101/1000
# 4/4 - 0s - loss: 0.1072 - val_loss: 0.1051 - 53ms/epoch - 13ms/step
# Epoch 102/1000
# 4/4 - 0s - loss: 0.1085 - val_loss: 0.0971 - 39ms/epoch - 10ms/step
# Epoch 103/1000
# 4/4 - 0s - loss: 0.1061 - val_loss: 0.1136 - 37ms/epoch - 9ms/step
# Epoch 104/1000
# 4/4 - 0s - loss: 0.1059 - val_loss: 0.1102 - 57ms/epoch - 14ms/step
# Epoch 105/1000
# 4/4 - 0s - loss: 0.1050 - val_loss: 0.0961 - 44ms/epoch - 11ms/step
# Epoch 106/1000
# 4/4 - 0s - loss: 0.1031 - val_loss: 0.0971 - 56ms/epoch - 14ms/step
# Epoch 107/1000
# 4/4 - 0s - loss: 0.1028 - val_loss: 0.1089 - 58ms/epoch - 14ms/step
# Epoch 108/1000
# 4/4 - 0s - loss: 0.1027 - val_loss: 0.1020 - 41ms/epoch - 10ms/step
# Epoch 109/1000
# 4/4 - 0s - loss: 0.0991 - val_loss: 0.0872 - 39ms/epoch - 10ms/step
# Epoch 110/1000
# 4/4 - 0s - loss: 0.1024 - val_loss: 0.0871 - 41ms/epoch - 10ms/step
# Epoch 111/1000
# 4/4 - 0s - loss: 0.1000 - val_loss: 0.0965 - 58ms/epoch - 15ms/step
# Epoch 112/1000
# 4/4 - 0s - loss: 0.0980 - val_loss: 0.0999 - 40ms/epoch - 10ms/step
# Epoch 113/1000
# 4/4 - 0s - loss: 0.1018 - val_loss: 0.1027 - 56ms/epoch - 14ms/step
# Epoch 114/1000
# 4/4 - 0s - loss: 0.1010 - val_loss: 0.0855 - 41ms/epoch - 10ms/step
# Epoch 115/1000
# 4/4 - 0s - loss: 0.0977 - val_loss: 0.0953 - 38ms/epoch - 9ms/step
# Epoch 116/1000
# 4/4 - 0s - loss: 0.0969 - val_loss: 0.0951 - 43ms/epoch - 11ms/step
# Epoch 117/1000
# 4/4 - 0s - loss: 0.0951 - val_loss: 0.0831 - 63ms/epoch - 16ms/step
# Epoch 118/1000
# 4/4 - 0s - loss: 0.0955 - val_loss: 0.0844 - 54ms/epoch - 13ms/step
# Epoch 119/1000
# 4/4 - 0s - loss: 0.0941 - val_loss: 0.0853 - 54ms/epoch - 13ms/step
# Epoch 120/1000
# 4/4 - 0s - loss: 0.0931 - val_loss: 0.0864 - 37ms/epoch - 9ms/step
# Epoch 121/1000
# 4/4 - 0s - loss: 0.0928 - val_loss: 0.0845 - 37ms/epoch - 9ms/step
# Epoch 122/1000
# 4/4 - 0s - loss: 0.0929 - val_loss: 0.0812 - 39ms/epoch - 10ms/step
# Epoch 123/1000
# 4/4 - 0s - loss: 0.0914 - val_loss: 0.0886 - 37ms/epoch - 9ms/step
# Epoch 124/1000
# 4/4 - 0s - loss: 0.0932 - val_loss: 0.0914 - 38ms/epoch - 10ms/step
# Epoch 125/1000
# 4/4 - 0s - loss: 0.0920 - val_loss: 0.0757 - 39ms/epoch - 10ms/step
# Epoch 126/1000
# 4/4 - 0s - loss: 0.0931 - val_loss: 0.0812 - 53ms/epoch - 13ms/step
# Epoch 127/1000
# 4/4 - 0s - loss: 0.0898 - val_loss: 0.0788 - 39ms/epoch - 10ms/step
# Epoch 128/1000
# 4/4 - 0s - loss: 0.0895 - val_loss: 0.0835 - 44ms/epoch - 11ms/step
# Epoch 129/1000
# 4/4 - 0s - loss: 0.0895 - val_loss: 0.0845 - 39ms/epoch - 10ms/step
# Epoch 130/1000
# Restoring model weights from the end of the best epoch: 125.
# 4/4 - 0s - loss: 0.0883 - val_loss: 0.0909 - 66ms/epoch - 17ms/step
# Epoch 130: early stopping

# %% [markdown]
# There are a number of parameters that are specified to the **EarlyStopping** object.
#
# * **min_delta** This value should be kept small. It simply means the minimum change in error to be registered as an improvement.  Setting it even smaller will not likely have a great deal of impact.
# * **patience** How long should the training wait for the validation error to improve?
# * **verbose** How much progress information do you want?
# * **mode** In general, always set this to "auto".  This allows you to specify if the error should be minimized or maximized.  Consider accuracy, where higher numbers are desired vs log-loss/RMSE where lower numbers are desired.
# * **restore_best_weights** This should always be set to true.  This restores the weights to the values they were at when the validation set is the highest.  Unless you are manually tracking the weights yourself (we do not use this technique in this course), you should have Keras perform this step for you.
#
# As you can see from above, the entire number of requested epochs were not used.  The neural network training stopped once the validation set no longer improved.

# %%
from sklearn.metrics import accuracy_score

pred = model.predict(X_test)
predict_classes = np.argmax(pred,axis=1)
expected_classes = np.argmax(y_test,axis=1)
correct = accuracy_score(expected_classes,predict_classes)
print(f"Accuracy: {correct}")
# Out:
# 2/2 [==============================] - 0s 8ms/step
# Accuracy: 0.9736842105263158

# %% [markdown]
# ### Early Stopping with Regression

# %%
# !wget https://data.heatonresearch.com/data/t81-558/auto-mpg.csv
# Out:
# --2024-01-24 22:13:05--  https://data.heatonresearch.com/data/t81-558/auto-mpg.csv
# Resolving data.heatonresearch.com (data.heatonresearch.com)... 108.157.162.19, 108.157.162.8, 108.157.162.56, ...
# Connecting to data.heatonresearch.com (data.heatonresearch.com)|108.157.162.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18121 (18K) [text/csv]
# Saving to: ‘auto-mpg.csv’
#
# auto-mpg.csv        100%[===================>]  17.70K  --.-KB/s    in 0s
#
# 2024-01-24 22:13:06 (198 MB/s) - ‘auto-mpg.csv’ saved [18121/18121]

# %%
import pandas as pd
import numpy as np
from sklearn import metrics

df = pd.read_csv('auto-mpg.csv', na_values=['NA', '?'])
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 393  27.0          4         140.0        86.0    2790          15.6    82
# 394  44.0          4          97.0        52.0    2130          24.6    82
# 395  32.0          4         135.0        84.0    2295          11.6    82
# 396  28.0          4         120.0        79.0    2625          18.6    82
# 397  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 393       1            ford mustang gl
# 394       2                  vw pickup
# 395       1              dodge rampage
# 396       1                ford ranger
# 397       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())

# Pandas to Numpy
X = df[['cylinders', 'displacement', 'horsepower', 'weight','acceleration', 'year', 'origin']].values
y = df['mpg'].values # regression

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Step 3: Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled,y,
                                                    test_size=0.2,
                                                    random_state=667
                                                    )

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential()
model.add(Dense(25, input_dim=X.shape[1], activation='relu')) # Hidden 1
model.add(Dense(10, activation='relu')) # Hidden 2

model.add(Dense(1)) # Output regression

model.compile(loss='mean_squared_error', optimizer='adam') # regression

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 25)                200
#
#  dense_13 (Dense)            (None, 10)                260
#
#  dense_14 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 471 (1.84 KB)
# Trainable params: 471 (1.84 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
monitor = EarlyStopping(monitor='val_loss',
                        min_delta=1e-3,
                        patience=5,
                        verbose=1,
                        mode='auto',
                        restore_best_weights=True)

model.fit(X_train,y_train,
          validation_data=(X_test,y_test),
          callbacks=[monitor],
          verbose=2,
          epochs=1000
          )
# Out:
# Epoch 1/1000
# 10/10 - 1s - loss: 621.2048 - val_loss: 543.8117 - 1s/epoch - 110ms/step
# Epoch 2/1000
# 10/10 - 0s - loss: 614.6876 - val_loss: 537.6483 - 66ms/epoch - 7ms/step
# Epoch 3/1000
# 10/10 - 0s - loss: 608.1035 - val_loss: 530.6010 - 50ms/epoch - 5ms/step
# Epoch 4/1000
# 10/10 - 0s - loss: 600.0046 - val_loss: 521.6755 - 67ms/epoch - 7ms/step
# Epoch 5/1000
# 10/10 - 0s - loss: 589.5901 - val_loss: 510.4449 - 66ms/epoch - 7ms/step
# Epoch 6/1000
# 10/10 - 0s - loss: 576.0862 - val_loss: 496.1087 - 67ms/epoch - 7ms/step
# Epoch 7/1000
# 10/10 - 0s - loss: 559.1260 - val_loss: 477.8607 - 53ms/epoch - 5ms/step
# Epoch 8/1000
# 10/10 - 0s - loss: 537.2171 - val_loss: 455.5360 - 51ms/epoch - 5ms/step
# Epoch 9/1000
# 10/10 - 0s - loss: 511.2726 - val_loss: 429.8179 - 59ms/epoch - 6ms/step
# Epoch 10/1000
# 10/10 - 0s - loss: 481.4557 - val_loss: 400.8863 - 53ms/epoch - 5ms/step
# Epoch 11/1000
# 10/10 - 0s - loss: 448.0124 - val_loss: 368.9013 - 68ms/epoch - 7ms/step
# Epoch 12/1000
# 10/10 - 0s - loss: 412.1237 - val_loss: 334.1679 - 64ms/epoch - 6ms/step
# Epoch 13/1000
# 10/10 - 0s - loss: 373.4274 - val_loss: 298.0438 - 68ms/epoch - 7ms/step
# Epoch 14/1000
# 10/10 - 0s - loss: 331.9615 - val_loss: 262.1896 - 55ms/epoch - 6ms/step
# Epoch 15/1000
# 10/10 - 0s - loss: 291.3362 - val_loss: 226.8828 - 68ms/epoch - 7ms/step
# Epoch 16/1000
# 10/10 - 0s - loss: 252.1155 - val_loss: 193.6667 - 68ms/epoch - 7ms/step
# Epoch 17/1000
# 10/10 - 0s - loss: 214.7755 - val_loss: 165.0611 - 69ms/epoch - 7ms/step
# Epoch 18/1000
# 10/10 - 0s - loss: 182.9289 - val_loss: 141.9355 - 53ms/epoch - 5ms/step
# Epoch 19/1000
# 10/10 - 0s - loss: 156.4278 - val_loss: 125.0198 - 71ms/epoch - 7ms/step
# Epoch 20/1000
# 10/10 - 0s - loss: 137.3639 - val_loss: 112.9560 - 84ms/epoch - 8ms/step
# Epoch 21/1000
# 10/10 - 0s - loss: 122.7816 - val_loss: 104.8294 - 66ms/epoch - 7ms/step
# Epoch 22/1000
# 10/10 - 0s - loss: 112.4434 - val_loss: 98.6217 - 50ms/epoch - 5ms/step
# Epoch 23/1000
# 10/10 - 0s - loss: 103.9268 - val_loss: 93.2546 - 59ms/epoch - 6ms/step
# Epoch 24/1000
# 10/10 - 0s - loss: 97.1204 - val_loss: 88.1101 - 67ms/epoch - 7ms/step
# Epoch 25/1000
# 10/10 - 0s - loss: 90.8986 - val_loss: 82.9241 - 71ms/epoch - 7ms/step
# Epoch 26/1000
# 10/10 - 0s - loss: 84.9670 - val_loss: 77.6819 - 72ms/epoch - 7ms/step
# Epoch 27/1000
# 10/10 - 0s - loss: 79.0320 - val_loss: 72.5598 - 51ms/epoch - 5ms/step
# Epoch 28/1000
# 10/10 - 0s - loss: 73.5109 - val_loss: 67.3332 - 68ms/epoch - 7ms/step
# Epoch 29/1000
# 10/10 - 0s - loss: 67.7288 - val_loss: 62.0172 - 58ms/epoch - 6ms/step
# Epoch 30/1000
# 10/10 - 0s - loss: 62.3236 - val_loss: 57.0360 - 52ms/epoch - 5ms/step
# Epoch 31/1000
# 10/10 - 0s - loss: 57.0596 - val_loss: 52.2017 - 64ms/epoch - 6ms/step
# Epoch 32/1000
# 10/10 - 0s - loss: 52.0890 - val_loss: 47.9837 - 53ms/epoch - 5ms/step
# Epoch 33/1000
# 10/10 - 0s - loss: 47.3904 - val_loss: 44.1994 - 51ms/epoch - 5ms/step
# Epoch 34/1000
# 10/10 - 0s - loss: 43.3843 - val_loss: 40.7394 - 69ms/epoch - 7ms/step
# Epoch 35/1000
# 10/10 - 0s - loss: 39.4933 - val_loss: 37.8826 - 71ms/epoch - 7ms/step
# Epoch 36/1000
# 10/10 - 0s - loss: 36.2034 - val_loss: 35.1576 - 53ms/epoch - 5ms/step
# Epoch 37/1000
# 10/10 - 0s - loss: 33.4256 - val_loss: 32.9280 - 49ms/epoch - 5ms/step
# Epoch 38/1000
# 10/10 - 0s - loss: 30.9991 - val_loss: 31.3238 - 52ms/epoch - 5ms/step
# Epoch 39/1000
# 10/10 - 0s - loss: 29.1918 - val_loss: 30.0344 - 75ms/epoch - 7ms/step
# Epoch 40/1000
# 10/10 - 0s - loss: 27.5942 - val_loss: 29.0802 - 67ms/epoch - 7ms/step
# Epoch 41/1000
# 10/10 - 0s - loss: 26.5199 - val_loss: 28.4081 - 52ms/epoch - 5ms/step
# Epoch 42/1000
# 10/10 - 0s - loss: 25.6223 - val_loss: 27.7858 - 51ms/epoch - 5ms/step
# Epoch 43/1000
# 10/10 - 0s - loss: 24.7901 - val_loss: 27.3411 - 67ms/epoch - 7ms/step
# Epoch 44/1000
# 10/10 - 0s - loss: 24.2347 - val_loss: 26.9902 - 52ms/epoch - 5ms/step
# Epoch 45/1000
# 10/10 - 0s - loss: 23.7193 - val_loss: 26.5929 - 71ms/epoch - 7ms/step
# Epoch 46/1000
# 10/10 - 0s - loss: 23.3255 - val_loss: 26.2398 - 52ms/epoch - 5ms/step
# Epoch 47/1000
# 10/10 - 0s - loss: 22.9274 - val_loss: 25.9774 - 67ms/epoch - 7ms/step
# Epoch 48/1000
# 10/10 - 0s - loss: 22.6198 - val_loss: 25.6112 - 67ms/epoch - 7ms/step
# Epoch 49/1000
# 10/10 - 0s - loss: 22.2782 - val_loss: 25.2871 - 76ms/epoch - 8ms/step
# Epoch 50/1000
# 10/10 - 0s - loss: 21.9752 - val_loss: 24.9802 - 53ms/epoch - 5ms/step
# Epoch 51/1000
# 10/10 - 0s - loss: 21.7048 - val_loss: 24.7467 - 56ms/epoch - 6ms/step
# Epoch 52/1000
# 10/10 - 0s - loss: 21.4135 - val_loss: 24.4206 - 56ms/epoch - 6ms/step
# Epoch 53/1000
# 10/10 - 0s - loss: 21.1281 - val_loss: 24.0454 - 50ms/epoch - 5ms/step
# Epoch 54/1000
# 10/10 - 0s - loss: 20.8791 - val_loss: 23.7210 - 52ms/epoch - 5ms/step
# Epoch 55/1000
# 10/10 - 0s - loss: 20.5801 - val_loss: 23.4887 - 71ms/epoch - 7ms/step
# Epoch 56/1000
# 10/10 - 0s - loss: 20.3904 - val_loss: 23.1678 - 53ms/epoch - 5ms/step
# Epoch 57/1000
# 10/10 - 0s - loss: 20.0912 - val_loss: 22.9584 - 67ms/epoch - 7ms/step
# Epoch 58/1000
# 10/10 - 0s - loss: 19.8573 - val_loss: 22.6773 - 70ms/epoch - 7ms/step
# Epoch 59/1000
# 10/10 - 0s - loss: 19.6162 - val_loss: 22.3414 - 74ms/epoch - 7ms/step
# Epoch 60/1000
# 10/10 - 0s - loss: 19.3923 - val_loss: 22.0467 - 68ms/epoch - 7ms/step
# Epoch 61/1000
# 10/10 - 0s - loss: 19.1746 - val_loss: 21.8059 - 54ms/epoch - 5ms/step
# Epoch 62/1000
# 10/10 - 0s - loss: 18.9230 - val_loss: 21.5457 - 71ms/epoch - 7ms/step
# Epoch 63/1000
# 10/10 - 0s - loss: 18.7540 - val_loss: 21.2817 - 79ms/epoch - 8ms/step
# Epoch 64/1000
# 10/10 - 0s - loss: 18.4905 - val_loss: 21.0670 - 59ms/epoch - 6ms/step
# Epoch 65/1000
# 10/10 - 0s - loss: 18.3204 - val_loss: 20.8336 - 59ms/epoch - 6ms/step
# Epoch 66/1000
# 10/10 - 0s - loss: 18.1046 - val_loss: 20.5607 - 54ms/epoch - 5ms/step
# Epoch 67/1000
# 10/10 - 0s - loss: 17.9212 - val_loss: 20.3128 - 81ms/epoch - 8ms/step
# Epoch 68/1000
# 10/10 - 0s - loss: 17.7374 - val_loss: 20.0830 - 57ms/epoch - 6ms/step
# Epoch 69/1000
# 10/10 - 0s - loss: 17.5372 - val_loss: 19.8563 - 77ms/epoch - 8ms/step
# Epoch 70/1000
# 10/10 - 0s - loss: 17.3666 - val_loss: 19.6366 - 55ms/epoch - 6ms/step
# Epoch 71/1000
# 10/10 - 0s - loss: 17.1619 - val_loss: 19.4707 - 97ms/epoch - 10ms/step
# Epoch 72/1000
# 10/10 - 0s - loss: 17.0795 - val_loss: 19.2192 - 83ms/epoch - 8ms/step
# Epoch 73/1000
# 10/10 - 0s - loss: 16.8777 - val_loss: 19.1261 - 91ms/epoch - 9ms/step
# Epoch 74/1000
# 10/10 - 0s - loss: 16.6748 - val_loss: 18.8688 - 99ms/epoch - 10ms/step
# Epoch 75/1000
# 10/10 - 0s - loss: 16.5271 - val_loss: 18.6774 - 79ms/epoch - 8ms/step
# Epoch 76/1000
# 10/10 - 0s - loss: 16.4011 - val_loss: 18.4723 - 96ms/epoch - 10ms/step
# Epoch 77/1000
# 10/10 - 0s - loss: 16.2786 - val_loss: 18.4149 - 92ms/epoch - 9ms/step
# Epoch 78/1000
# 10/10 - 0s - loss: 16.1538 - val_loss: 18.1379 - 112ms/epoch - 11ms/step
# Epoch 79/1000
# 10/10 - 0s - loss: 15.9991 - val_loss: 17.9396 - 90ms/epoch - 9ms/step
# Epoch 80/1000
# 10/10 - 0s - loss: 15.8161 - val_loss: 17.9906 - 74ms/epoch - 7ms/step
# Epoch 81/1000
# 10/10 - 0s - loss: 15.7379 - val_loss: 17.7338 - 89ms/epoch - 9ms/step
# Epoch 82/1000
# 10/10 - 0s - loss: 15.6219 - val_loss: 17.5831 - 93ms/epoch - 9ms/step
# Epoch 83/1000
# 10/10 - 0s - loss: 15.4730 - val_loss: 17.3101 - 79ms/epoch - 8ms/step
# Epoch 84/1000
# 10/10 - 0s - loss: 15.2674 - val_loss: 17.1794 - 103ms/epoch - 10ms/step
# Epoch 85/1000
# 10/10 - 0s - loss: 15.1448 - val_loss: 17.1206 - 98ms/epoch - 10ms/step
# Epoch 86/1000
# 10/10 - 0s - loss: 15.0105 - val_loss: 16.9257 - 95ms/epoch - 9ms/step
# Epoch 87/1000
# 10/10 - 0s - loss: 14.8737 - val_loss: 16.7934 - 96ms/epoch - 10ms/step
# Epoch 88/1000
# 10/10 - 0s - loss: 14.7358 - val_loss: 16.6054 - 95ms/epoch - 10ms/step
# Epoch 89/1000
# 10/10 - 0s - loss: 14.6350 - val_loss: 16.4685 - 97ms/epoch - 10ms/step
# Epoch 90/1000
# 10/10 - 0s - loss: 14.4943 - val_loss: 16.3143 - 99ms/epoch - 10ms/step
# Epoch 91/1000
# 10/10 - 0s - loss: 14.4103 - val_loss: 16.2189 - 83ms/epoch - 8ms/step
# Epoch 92/1000
# 10/10 - 0s - loss: 14.2491 - val_loss: 16.0804 - 82ms/epoch - 8ms/step
# Epoch 93/1000
# 10/10 - 0s - loss: 14.1558 - val_loss: 15.8883 - 89ms/epoch - 9ms/step
# Epoch 94/1000
# 10/10 - 0s - loss: 14.0401 - val_loss: 15.8083 - 92ms/epoch - 9ms/step
# Epoch 95/1000
# 10/10 - 0s - loss: 13.9435 - val_loss: 15.7129 - 54ms/epoch - 5ms/step
# Epoch 96/1000
# 10/10 - 0s - loss: 13.8039 - val_loss: 15.4713 - 64ms/epoch - 6ms/step
# Epoch 97/1000
# 10/10 - 0s - loss: 13.7298 - val_loss: 15.2885 - 55ms/epoch - 6ms/step
# Epoch 98/1000
# 10/10 - 0s - loss: 13.6176 - val_loss: 15.3183 - 71ms/epoch - 7ms/step
# Epoch 99/1000
# 10/10 - 0s - loss: 13.4728 - val_loss: 15.1491 - 69ms/epoch - 7ms/step
# Epoch 100/1000
# 10/10 - 0s - loss: 13.3653 - val_loss: 14.9238 - 56ms/epoch - 6ms/step
# Epoch 101/1000
# 10/10 - 0s - loss: 13.2685 - val_loss: 14.7934 - 69ms/epoch - 7ms/step
# Epoch 102/1000
# 10/10 - 0s - loss: 13.1675 - val_loss: 14.7971 - 61ms/epoch - 6ms/step
# Epoch 103/1000
# 10/10 - 0s - loss: 13.0608 - val_loss: 14.6195 - 67ms/epoch - 7ms/step
# Epoch 104/1000
# 10/10 - 0s - loss: 12.9645 - val_loss: 14.5295 - 60ms/epoch - 6ms/step
# Epoch 105/1000
# 10/10 - 0s - loss: 12.8700 - val_loss: 14.3819 - 51ms/epoch - 5ms/step
# Epoch 106/1000
# 10/10 - 0s - loss: 12.7925 - val_loss: 14.2940 - 60ms/epoch - 6ms/step
# Epoch 107/1000
# 10/10 - 0s - loss: 12.6745 - val_loss: 14.1955 - 51ms/epoch - 5ms/step
# Epoch 108/1000
# 10/10 - 0s - loss: 12.5942 - val_loss: 14.0240 - 51ms/epoch - 5ms/step
# Epoch 109/1000
# 10/10 - 0s - loss: 12.4929 - val_loss: 13.9868 - 71ms/epoch - 7ms/step
# Epoch 110/1000
# 10/10 - 0s - loss: 12.4007 - val_loss: 13.8259 - 53ms/epoch - 5ms/step
# Epoch 111/1000
# 10/10 - 0s - loss: 12.3179 - val_loss: 13.7496 - 59ms/epoch - 6ms/step
# Epoch 112/1000
# 10/10 - 0s - loss: 12.2595 - val_loss: 13.6700 - 53ms/epoch - 5ms/step
# Epoch 113/1000
# 10/10 - 0s - loss: 12.1864 - val_loss: 13.4499 - 51ms/epoch - 5ms/step
# Epoch 114/1000
# 10/10 - 0s - loss: 12.0859 - val_loss: 13.3981 - 53ms/epoch - 5ms/step
# Epoch 115/1000
# 10/10 - 0s - loss: 12.0029 - val_loss: 13.3312 - 53ms/epoch - 5ms/step
# Epoch 116/1000
# 10/10 - 0s - loss: 11.9608 - val_loss: 13.3458 - 58ms/epoch - 6ms/step
# Epoch 117/1000
# 10/10 - 0s - loss: 11.8472 - val_loss: 13.1249 - 54ms/epoch - 5ms/step
# Epoch 118/1000
# 10/10 - 0s - loss: 11.8022 - val_loss: 12.9845 - 67ms/epoch - 7ms/step
# Epoch 119/1000
# 10/10 - 0s - loss: 11.7266 - val_loss: 12.9218 - 72ms/epoch - 7ms/step
# Epoch 120/1000
# 10/10 - 0s - loss: 11.7181 - val_loss: 12.7394 - 51ms/epoch - 5ms/step
# Epoch 121/1000
# 10/10 - 0s - loss: 11.5664 - val_loss: 12.7463 - 81ms/epoch - 8ms/step
# Epoch 122/1000
# 10/10 - 0s - loss: 11.5199 - val_loss: 12.7932 - 70ms/epoch - 7ms/step
# Epoch 123/1000
# 10/10 - 0s - loss: 11.4422 - val_loss: 12.5851 - 51ms/epoch - 5ms/step
# Epoch 124/1000
# 10/10 - 0s - loss: 11.3733 - val_loss: 12.4492 - 50ms/epoch - 5ms/step
# Epoch 125/1000
# 10/10 - 0s - loss: 11.3265 - val_loss: 12.2956 - 58ms/epoch - 6ms/step
# Epoch 126/1000
# 10/10 - 0s - loss: 11.2745 - val_loss: 12.3253 - 68ms/epoch - 7ms/step
# Epoch 127/1000
# 10/10 - 0s - loss: 11.1967 - val_loss: 12.2010 - 56ms/epoch - 6ms/step
# Epoch 128/1000
# 10/10 - 0s - loss: 11.1331 - val_loss: 12.0621 - 57ms/epoch - 6ms/step
# Epoch 129/1000
# 10/10 - 0s - loss: 11.0672 - val_loss: 12.1017 - 69ms/epoch - 7ms/step
# Epoch 130/1000
# 10/10 - 0s - loss: 11.0101 - val_loss: 11.9499 - 71ms/epoch - 7ms/step
# Epoch 131/1000
# 10/10 - 0s - loss: 10.9262 - val_loss: 11.8290 - 55ms/epoch - 5ms/step
# Epoch 132/1000
# 10/10 - 0s - loss: 10.8721 - val_loss: 11.7324 - 75ms/epoch - 8ms/step
# Epoch 133/1000
# 10/10 - 0s - loss: 10.8233 - val_loss: 11.6675 - 57ms/epoch - 6ms/step
# Epoch 134/1000
# 10/10 - 0s - loss: 10.7683 - val_loss: 11.6543 - 66ms/epoch - 7ms/step
# Epoch 135/1000
# 10/10 - 0s - loss: 10.7032 - val_loss: 11.5362 - 63ms/epoch - 6ms/step
# Epoch 136/1000
# 10/10 - 0s - loss: 10.6612 - val_loss: 11.4060 - 73ms/epoch - 7ms/step
# Epoch 137/1000
# 10/10 - 0s - loss: 10.6276 - val_loss: 11.4591 - 78ms/epoch - 8ms/step
# Epoch 138/1000
# 10/10 - 0s - loss: 10.5645 - val_loss: 11.2705 - 70ms/epoch - 7ms/step
# Epoch 139/1000
# 10/10 - 0s - loss: 10.5885 - val_loss: 11.1052 - 51ms/epoch - 5ms/step
# Epoch 140/1000
# 10/10 - 0s - loss: 10.4522 - val_loss: 11.2833 - 64ms/epoch - 6ms/step
# Epoch 141/1000
# 10/10 - 0s - loss: 10.4274 - val_loss: 11.2200 - 70ms/epoch - 7ms/step
# Epoch 142/1000
# 10/10 - 0s - loss: 10.3512 - val_loss: 10.9223 - 50ms/epoch - 5ms/step
# Epoch 143/1000
# 10/10 - 0s - loss: 10.3249 - val_loss: 10.8465 - 52ms/epoch - 5ms/step
# Epoch 144/1000
# 10/10 - 0s - loss: 10.2671 - val_loss: 10.8811 - 54ms/epoch - 5ms/step
# Epoch 145/1000
# 10/10 - 0s - loss: 10.2268 - val_loss: 10.7139 - 57ms/epoch - 6ms/step
# Epoch 146/1000
# 10/10 - 0s - loss: 10.1551 - val_loss: 10.8247 - 55ms/epoch - 5ms/step
# Epoch 147/1000
# 10/10 - 0s - loss: 10.1162 - val_loss: 10.6854 - 57ms/epoch - 6ms/step
# Epoch 148/1000
# 10/10 - 0s - loss: 10.0971 - val_loss: 10.6795 - 79ms/epoch - 8ms/step
# Epoch 149/1000
# 10/10 - 0s - loss: 10.0314 - val_loss: 10.5151 - 57ms/epoch - 6ms/step
# Epoch 150/1000
# 10/10 - 0s - loss: 9.9982 - val_loss: 10.4746 - 51ms/epoch - 5ms/step
# Epoch 151/1000
# 10/10 - 0s - loss: 9.9415 - val_loss: 10.3394 - 67ms/epoch - 7ms/step
# Epoch 152/1000
# 10/10 - 0s - loss: 9.8994 - val_loss: 10.3451 - 71ms/epoch - 7ms/step
# Epoch 153/1000
# 10/10 - 0s - loss: 9.8786 - val_loss: 10.2678 - 54ms/epoch - 5ms/step
# Epoch 154/1000
# 10/10 - 0s - loss: 9.8282 - val_loss: 10.2759 - 50ms/epoch - 5ms/step
# Epoch 155/1000
# 10/10 - 0s - loss: 9.8009 - val_loss: 10.0965 - 50ms/epoch - 5ms/step
# Epoch 156/1000
# 10/10 - 0s - loss: 9.7555 - val_loss: 10.1116 - 51ms/epoch - 5ms/step
# Epoch 157/1000
# 10/10 - 0s - loss: 9.7431 - val_loss: 10.1406 - 57ms/epoch - 6ms/step
# Epoch 158/1000
# 10/10 - 0s - loss: 9.6862 - val_loss: 9.9168 - 75ms/epoch - 7ms/step
# Epoch 159/1000
# 10/10 - 0s - loss: 9.6688 - val_loss: 9.9548 - 69ms/epoch - 7ms/step
# Epoch 160/1000
# 10/10 - 0s - loss: 9.6395 - val_loss: 9.8046 - 53ms/epoch - 5ms/step
# Epoch 161/1000
# 10/10 - 0s - loss: 9.6254 - val_loss: 9.9543 - 52ms/epoch - 5ms/step
# Epoch 162/1000
# 10/10 - 0s - loss: 9.5674 - val_loss: 9.7205 - 54ms/epoch - 5ms/step
# Epoch 163/1000
# 10/10 - 0s - loss: 9.5233 - val_loss: 9.7946 - 51ms/epoch - 5ms/step
# Epoch 164/1000
# 10/10 - 0s - loss: 9.4910 - val_loss: 9.6855 - 64ms/epoch - 6ms/step
# Epoch 165/1000
# 10/10 - 0s - loss: 9.4431 - val_loss: 9.6719 - 53ms/epoch - 5ms/step
# Epoch 166/1000
# 10/10 - 0s - loss: 9.4979 - val_loss: 9.4747 - 57ms/epoch - 6ms/step
# Epoch 167/1000
# 10/10 - 0s - loss: 9.4731 - val_loss: 9.7829 - 52ms/epoch - 5ms/step
# Epoch 168/1000
# 10/10 - 0s - loss: 9.3794 - val_loss: 9.3813 - 72ms/epoch - 7ms/step
# Epoch 169/1000
# 10/10 - 0s - loss: 9.3356 - val_loss: 9.4520 - 82ms/epoch - 8ms/step
# Epoch 170/1000
# 10/10 - 0s - loss: 9.3153 - val_loss: 9.4679 - 66ms/epoch - 7ms/step
# Epoch 171/1000
# 10/10 - 0s - loss: 9.3045 - val_loss: 9.3088 - 66ms/epoch - 7ms/step
# Epoch 172/1000
# 10/10 - 0s - loss: 9.2464 - val_loss: 9.2177 - 70ms/epoch - 7ms/step
# Epoch 173/1000
# 10/10 - 0s - loss: 9.2535 - val_loss: 9.3640 - 67ms/epoch - 7ms/step
# Epoch 174/1000
# 10/10 - 0s - loss: 9.2049 - val_loss: 9.2110 - 56ms/epoch - 6ms/step
# Epoch 175/1000
# 10/10 - 0s - loss: 9.1756 - val_loss: 9.1638 - 68ms/epoch - 7ms/step
# Epoch 176/1000
# 10/10 - 0s - loss: 9.1414 - val_loss: 9.0330 - 54ms/epoch - 5ms/step
# Epoch 177/1000
# 10/10 - 0s - loss: 9.1485 - val_loss: 9.1011 - 55ms/epoch - 6ms/step
# Epoch 178/1000
# 10/10 - 0s - loss: 9.0950 - val_loss: 8.9042 - 52ms/epoch - 5ms/step
# Epoch 179/1000
# 10/10 - 0s - loss: 9.0823 - val_loss: 9.0158 - 52ms/epoch - 5ms/step
# Epoch 180/1000
# 10/10 - 0s - loss: 9.0511 - val_loss: 9.0005 - 66ms/epoch - 7ms/step
# Epoch 181/1000
# 10/10 - 0s - loss: 9.2073 - val_loss: 8.6860 - 68ms/epoch - 7ms/step
# Epoch 182/1000
# 10/10 - 0s - loss: 9.0558 - val_loss: 9.2107 - 67ms/epoch - 7ms/step
# Epoch 183/1000
# 10/10 - 0s - loss: 9.0419 - val_loss: 8.8505 - 72ms/epoch - 7ms/step
# Epoch 184/1000
# 10/10 - 0s - loss: 8.9698 - val_loss: 8.7593 - 60ms/epoch - 6ms/step
# Epoch 185/1000
# 10/10 - 0s - loss: 8.9411 - val_loss: 8.7875 - 62ms/epoch - 6ms/step
# Epoch 186/1000
# Restoring model weights from the end of the best epoch: 181.
# 10/10 - 0s - loss: 8.9283 - val_loss: 8.7227 - 63ms/epoch - 6ms/step
# Epoch 186: early stopping

# %%
# Measure RMSE error.  RMSE is common for regression.
y_pred = model.predict(X_test)
score = np.sqrt(metrics.mean_squared_error(y_pred,y_test))
print(f"Final score (RMSE): {score}")
# Out:
# 3/3 [==============================] - 0s 4ms/step
# Final score (RMSE): 2.94720086303077
