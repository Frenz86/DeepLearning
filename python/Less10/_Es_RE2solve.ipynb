# %% [markdown]
# ## Esercizi

# %%
from IPython.display import Image
Image('https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/reg.png',width=900)

# %%
Image('https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/reg1.jpg')

# %% [markdown]
# Riferimenti utili per usare la sintassi per creare regular expression
#
# | Character | Description                 || Character | Description                     |
# |-----------|-----------------------------||-----------|---------------------------------|
# | ``"\d"``  | Match any digit             || ``"\D"``  | Match any non-digit             |
# | ``"\s"``  | Match any whitespace        || ``"\S"``  | Match any non-whitespace        |
# | ``"\w"``  | Match any alphanumeric char || ``"\W"``  | Match any non-alphanumeric char |
#
# This is *not* a comprehensive list or description; for more details, see Python's [regular expression syntax documentation](https://docs.python.org/3/library/re.html#re-syntax).

# %%
# !wget https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/email_re.xlsx
# Out:
# --2025-03-03 19:07:26--  https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/email_re.xlsx
# Resolving frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)... 3.5.245.156, 3.5.245.154, 52.95.150.86, ...
# Connecting to frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)|3.5.245.156|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 339422 (331K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘email_re.xlsx’
#
# email_re.xlsx       100%[===================>] 331.47K   955KB/s    in 0.3s
#
# 2025-03-03 19:07:27 (955 KB/s) - ‘email_re.xlsx’ saved [339422/339422]

# %%
import re
import pandas as pd

df = pd.read_excel('email_re.xlsx')
df
# Out:
#                                          Message-ID          Date  \
# 0     <18782981.1075855378110.JavaMail.evans@thyme>  37025.985417
# 1     <15464986.1075855378456.JavaMail.evans@thyme>  37015.868750
# 2     <24216240.1075855687451.JavaMail.evans@thyme>  36817.416667
# 3     <13505866.1075863688222.JavaMail.evans@thyme>  36822.550694
# 4     <30922949.1075863688243.JavaMail.evans@thyme>  36769.504861
# ...                                             ...           ...
# 1230  <15816310.1075855374294.JavaMail.evans@thyme>  37026.012500
# 1231   <6521706.1075855374316.JavaMail.evans@thyme>  37026.012500
# 1232  <21543395.1075855374340.JavaMail.evans@thyme>  37255.763194
# 1233  <25363451.1075855374674.JavaMail.evans@thyme>  37253.052778
# 1234  <19705494.1075858631723.JavaMail.evans@thyme>  37182.931250
#
#                                                  From  \
# 0              frozenset({'phillip.allen@enron.com'})
# 1              frozenset({'phillip.allen@enron.com'})
# 2              frozenset({'phillip.allen@enron.com'})
# 3              frozenset({'phillip.allen@enron.com'})
# 4              frozenset({'phillip.allen@enron.com'})
# ...                                               ...
# 1230  frozenset({'outlook-migration-team@enron.com'})
# 1231  frozenset({'outlook-migration-team@enron.com'})
# 1232              frozenset({'pallen70@hotmail.com'})
# 1233        frozenset({'arsystem@mailman.enron.com'})
# 1234            frozenset({'webmaster@earnings.com'})
#
#                                           To  \
# 0        frozenset({'tim.belden@enron.com'})
# 1     frozenset({'john.lavorato@enron.com'})
# 2      frozenset({'leah.arsdall@enron.com'})
# 3       frozenset({'randall.gay@enron.com'})
# 4        frozenset({'greg.piper@enron.com'})
# ...                                      ...
# 1230                                     NaN
# 1231                                     NaN
# 1232         frozenset({'pallen@enron.com'})
# 1233       frozenset({'k..allen@enron.com'})
# 1234         frozenset({'pallen@enron.com'})
#
#                                                 Subject  \
# 0                                                   NaN
# 1                                                   Re:
# 2                                              Re: test
# 3                                                   NaN
# 4                                             Re: Hello
# ...                                                 ...
# 1230                                        Lee Odonnel
# 1231                                        Greg Thorse
# 1232                                Fwd: Bishops Corner
# 1233  Your Approval is Overdue: Access Request for m...
# 1234                            NT Earnings Information
#
#                                                  X-From  \
# 0                                       Phillip K Allen
# 1                                       Phillip K Allen
# 2                                       Phillip K Allen
# 3                                       Phillip K Allen
# 4                                       Phillip K Allen
# ...                                                 ...
# 1230  Outlook-Migration-Team </O=ENRON/OU=NA/CN=RECI...
# 1231  Outlook-Migration-Team </O=ENRON/OU=NA/CN=RECI...
# 1232       "phillip allen" <pallen70@hotmail.com>@ENRON
# 1233        ARSystem <ARSystem@mailman.enron.com>@ENRON
# 1234      "Earnings.com" <webmaster@earnings.com>@ENRON
#
#                                                    X-To X-cc  X-bcc  \
# 0              Tim Belden <Tim Belden/Enron@EnronXGate>  NaN    NaN
# 1     John J Lavorato <John J Lavorato/ENRON@enronXg...  NaN    NaN
# 2                                      Leah Van Arsdall  NaN    NaN
# 3                                         Randall L Gay  NaN    NaN
# 4                                            Greg Piper  NaN    NaN
# ...                                                 ...  ...    ...
# 1230                                                NaN  NaN    NaN
# 1231                                                NaN  NaN    NaN
# 1232                                   pallen@enron.com  NaN    NaN
# 1233  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...  NaN    NaN
# 1234                                   pallen@enron.com  NaN    NaN
#
#                                                X-Folder X-Origin  \
# 0     \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...  Allen-P
# 1     \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...  Allen-P
# 2       \Phillip_Allen_Dec2000\Notes Folders\'sent mail  Allen-P
# 3       \Phillip_Allen_Dec2000\Notes Folders\'sent mail  Allen-P
# 4       \Phillip_Allen_Dec2000\Notes Folders\'sent mail  Allen-P
# ...                                                 ...      ...
# 1230  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\Con...  Allen-P
# 1231  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\Con...  Allen-P
# 1232  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\Del...  Allen-P
# 1233  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\Del...  Allen-P
# 1234  \PALLEN (Non-Privileged)\Allen, Phillip K.\Del...  Allen-P
#
#                        X-FileName  \
# 0     pallen (Non-Privileged).pst
# 1     pallen (Non-Privileged).pst
# 2                      pallen.nsf
# 3                      pallen.nsf
# 4                      pallen.nsf
# ...                           ...
# 1230  pallen (Non-Privileged).pst
# 1231  pallen (Non-Privileged).pst
# 1232  pallen (Non-Privileged).pst
# 1233  pallen (Non-Privileged).pst
# 1234  PALLEN (Non-Privileged).pst
#
#                                                 content     user
# 0                                  Here is our forecast  allen-p
# 1     Traveling to have a business meeting takes the...  allen-p
# 2                         test successful. way to go!!!  allen-p
# 3     Randy, Can you send me a schedule of the salar...  allen-p
# 4                     Let's shoot for Tuesday at 11:45.  allen-p
# ...                                                 ...      ...
# 1230  loan servicing-jessica weeber 800-393-5626 jwe...  allen-p
# 1231                            exit mccollough off 410  allen-p
# 1232  >From: "Greg Thorse" >To: >CC: "Phillip Allen"...  allen-p
# 1233  This request has been pending your approval fo...  allen-p
# 1234  If you cannot read this email, please click he...      NaN
#
# [1235 rows x 14 columns]
