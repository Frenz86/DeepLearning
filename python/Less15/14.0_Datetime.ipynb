# %% [markdown]
# ## Datetime

# %% [markdown]
# <img src='https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/datetime.jpg' width=850>

# %%
from datetime import datetime

# %%
my_year = 2022
my_month = 12
my_day = 4
my_hour = 13
my_minute = 30
my_second = 15

# %%
my_date = datetime(my_year,my_month,my_day)

# %%
# Defaults to 0:00
my_date
# Out:
# datetime.datetime(2022, 12, 4, 0, 0)

# %%
my_date_time = datetime(my_year,my_month,my_day,my_hour,my_minute,my_second)
my_date_time
# Out:
# datetime.datetime(2022, 12, 4, 13, 30, 15)

# %% [markdown]
# ### Prendere una parte della data

# %%
my_date.day
# Out:
# 4

# %%
my_date_time.hour
# Out:
# 13

# %%
my_date_time.month
# Out:
# 12

# %% [markdown]
# ## NumPy Datetime Arrays

# %%
# NumPy data type is called datetime64 to distinguish it from Python's datetime
import numpy as np

# %%
np.array(['2018-03-15', '2019-05-24', '2020-08-09'])
# Out:
# array(['2018-03-15', '2019-05-24', '2020-08-09'], dtype='<U10')

# %%
# CREATE AN ARRAY FROM THREE DATES
np.array(['2018-03-15', '2019-05-24', '2020-08-09'], dtype='datetime64')
# Out:
# array(['2018-03-15', '2019-05-24', '2020-08-09'], dtype='datetime64[D]')

# %%
np.array(['2018-03-15', '2019-05-24', '2020-08-09'], dtype='datetime64[h]')
# Out:
# array(['2018-03-15T00', '2019-05-24T00', '2020-08-09T00'],
#       dtype='datetime64[h]')

# %%
np.array(['2016-03-15', '2017-05-24', '2018-08-09'], dtype='datetime64[Y]')
# Out:
# array(['2016', '2017', '2018'], dtype='datetime64[Y]')

# %% [markdown]
# ### Datetime Today + Timedelta

# %%
import datetime
today = datetime.date.today()
tomorrow = today + datetime.timedelta(days=1)
tomorrow
# Out:
# datetime.date(2025, 1, 20)

# %%
today
# Out:
# datetime.date(2025, 1, 19)

# %%
tomorrow
# Out:
# datetime.date(2025, 1, 20)

# %%
nextyear = today + datetime.timedelta(days=365)
nextyear
# Out:
# datetime.date(2026, 1, 19)

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 1, 19, 9, 39, 37, 546697)

# %% [markdown]
# ## NumPy Date Ranges

# %%
# np.arange(start,stop,step) can be used to produce an array of evenly-spaced integers,
# we can pass a dtype argument to obtain an array of dates

# %%
import numpy as np

# %%
# Spaced one week
np.arange('2018-06-01', '2018-06-23', 7, dtype='datetime64[D]')
# Out:
# array(['2018-06-01', '2018-06-08', '2018-06-15', '2018-06-22'],
#       dtype='datetime64[D]')

# %%
#  AN ARRAY OF DATES FOR EVERY month FROM
np.arange('2018-06-01', '2022-06-23', dtype='datetime64[M]')
# Out:
# array(['2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11',
#        '2018-12', '2019-01', '2019-02', '2019-03', '2019-04', '2019-05',
#        '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11',
#        '2019-12', '2020-01', '2020-02', '2020-03', '2020-04', '2020-05',
#        '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11',
#        '2020-12', '2021-01', '2021-02', '2021-03', '2021-04', '2021-05',
#        '2021-06', '2021-07', '2021-08', '2021-09', '2021-10', '2021-11',
#        '2021-12', '2022-01', '2022-02', '2022-03', '2022-04', '2022-05'],
#       dtype='datetime64[M]')

# %%
# AN ARRAY OF DATES FOR EVERY YEAR FROM 1968 TO 1975
np.arange('1968', '1976', dtype='datetime64[Y]')
# Out:
# array(['1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975'],
#       dtype='datetime64[Y]')

# %%
# AN ARRAY OF DATES FOR EVERY 2YEARS FROM 1968 TO 1975
#Solo gli anni pari
np.arange('1968', '1976',2, dtype='datetime64[Y]')
# Out:
# array(['1968', '1970', '1972', '1974'], dtype='datetime64[Y]')

# %% [markdown]
# ## Pandas Datetime Index

# %%
import pandas as pd
# Fortunately pandas has a lot of functions and methods to work with time series!

# %%
# THE WEEK Gennaio
idx = pd.date_range('4/19/2021', periods=7, freq='D')
idx
# Out:
# DatetimeIndex(['2021-04-19', '2021-04-20', '2021-04-21', '2021-04-22',
#                '2021-04-23', '2021-04-24', '2021-04-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Another way is to convert incoming text with the pd.to_datetime() method:

# %%
idx = pd.to_datetime(['Jan 02, 2021', '1/2/21', '02-Jan-2021', None], format='mixed')
idx
# Out:
# DatetimeIndex(['2021-01-02', '2021-01-02', '2021-01-02', 'NaT'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### Esercizio

# %%
import matplotlib.pyplot as plt
df = pd.DataFrame({
    'nome':['daniele','elisa','carlo','andrea','linda','alessandra'],
    'data_nascita':['01/21/1988','03/10/1977','07/25/1999','01/22/1977','09/30/1968','1970/09/15']
    })
df
# Out:
#          nome data_nascita
# 0     daniele   01/21/1988
# 1       elisa   03/10/1977
# 2       carlo   07/25/1999
# 3      andrea   01/22/1977
# 4       linda   09/30/1968
# 5  alessandra   1970/09/15

# %%
df.dtypes
# Out:
# nome            object
# data_nascita    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nome          6 non-null      object
#  1   data_nascita  6 non-null      object
# dtypes: object(2)
# memory usage: 228.0+ bytes

# %%
df['data_nascita'] = pd.to_datetime(df['data_nascita'],
                                    format='mixed',
                                    )

# %%
df
# Out:
#          nome data_nascita
# 0     daniele   1988-01-21
# 1       elisa   1977-03-10
# 2       carlo   1999-07-25
# 3      andrea   1977-01-22
# 4       linda   1968-09-30
# 5  alessandra   1970-09-15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nome          6 non-null      object
#  1   data_nascita  6 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 228.0+ bytes

# %%
df['data_nascita'].map(lambda d: d.month).plot(kind='hist')
plt.xlabel('Mesi');

# %%
df['data_nascita'].map(lambda d: d.year).plot(kind='hist')
plt.xlabel('Anni');

# %%
df['data_nascita'].map(lambda d: d.day).plot(kind='hist')
plt.xlabel('giorni');

# %%
#############################

# %%
df =pd.read_csv('https://frenzy86.s3.eu-west-2.amazonaws.com/fav/company_sales_data.csv')
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
import calendar
for m in range(1, 13):
    print(calendar.month_name[m])
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
month = {
1:'January',
2:'February',
3:'March',
4:'April',
5:'May',
6:'June',
7:'July',
8:'August',
9:'September',
10:'October',
11:'November',
12:'December'
}

# %%
df['month_number'] = df['month_number'].map(month)
df
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0       January       2500      1500        5200         9200     1200
# 1      February       2630      1200        5100         6100     2100
# 2         March       2140      1340        4550         9550     3550
# 3         April       3400      1130        5870         8870     1870
# 4           May       3600      1740        4560         7760     1560
# 5          June       2760      1555        4890         7490     1890
# 6          July       2980      1120        4780         8980     1780
# 7        August       3700      1400        5860         9960     2860
# 8     September       3540      1780        6100         8100     2100
# 9       October       1990      1890        8300        10300     2300
# 10     November       2340      2100        7300        13300     2400
# 11     December       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# ...

# %%
#####################################################à

# %% [markdown]
# ## Convert array DT to an index

# %%
# Create a NumPy datetime array and convert to pandas index
some_dates = np.array(['2018-03-15', '2019-05-24', '2020-08-09'], dtype='datetime64')
some_dates
# Out:
# array(['2018-03-15', '2019-05-24', '2020-08-09'], dtype='datetime64[D]')

# %%
# Convert to an index
idx = pd.DatetimeIndex(some_dates)
idx
# Out:
# DatetimeIndex(['2018-03-15', '2019-05-24', '2020-08-09'], dtype='datetime64[s]', freq=None)

# %%
# To set an existing column as the index, use .set_index()
# df.set_index('Date',inplace=True)

# %% [markdown]
# ## Pandas Datetime Analysis

# %%
# Create some random data
data = np.random.randn(3,2)
cols = ['A','B']
print(data)
# Out:
# [[-1.4474554   0.27643951]
#  [ 0.31226814  0.01975723]
#  [-0.62152938  0.44865009]]

# %%
# Create a DataFrame with our random data, our date index, and our columns
df = pd.DataFrame(data,idx,cols)
df
# Out:
#                    A         B
# 2018-03-15 -1.447455  0.276440
# 2019-05-24  0.312268  0.019757
# 2020-08-09 -0.621529  0.448650

# %%
df.index
# Out:
# DatetimeIndex(['2018-03-15', '2019-05-24', '2020-08-09'], dtype='datetime64[s]', freq=None)

# %%
# Latest Date Value
df.index.max()
# Out:
# Timestamp('2020-08-09 00:00:00')

# %%
# Latest Date Index Location
df.index.argmax() #ultima posizione index2
# Out:
# 2

# %%
# Earliest Date Value
df.index.min()
# Out:
# Timestamp('2018-03-15 00:00:00')

# %%
# Earliest Date Index Location
df.index.argmin()
# Out:
# 0

# %% [markdown]
# ## Time Resampling

# %%
#!wget  https://frenzy86.s3.eu-west-2.amazonaws.com/timeseries/Data/starbucks.csv
starbucks ='https://frenzy86.s3.eu-west-2.amazonaws.com/timeseries/Data/starbucks.csv'

# %%
df = pd.read_csv(starbucks)
df
# Out:
#             Date    Close    Volume
# 0     2015-01-02  38.0061   6906098
# 1     2015-01-05  37.2781  11623796
# 2     2015-01-06  36.9748   7664340
# 3     2015-01-07  37.8848   9732554
# 4     2015-01-08  38.4961  13170548
# ...          ...      ...       ...
# 1001  2018-12-24  60.5600   6323252
# 1002  2018-12-26  63.0800  16646238
# 1003  2018-12-27  63.2000  11308081
# 1004  2018-12-28  63.3900   7712127
# 1005  2018-12-31  64.4000   7690183
#
# [1006 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1006 entries, 0 to 1005
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1006 non-null   object
#  1   Close   1006 non-null   float64
#  2   Volume  1006 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 23.7+ KB

# %%
df = pd.read_csv(starbucks,
                 index_col='Date',
                 parse_dates=True
                 )
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
df
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548
# ...             ...       ...
# 2018-12-24  60.5600   6323252
# 2018-12-26  63.0800  16646238
# 2018-12-27  63.2000  11308081
# 2018-12-28  63.3900   7712127
# 2018-12-31  64.4000   7690183
#
# [1006 rows x 2 columns]

# %%
df = pd.read_csv(starbucks,
                 index_col='Date',
                 parse_dates=True
                 )
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
df
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548
# ...             ...       ...
# 2018-12-24  60.5600   6323252
# 2018-12-26  63.0800  16646238
# 2018-12-27  63.2000  11308081
# 2018-12-28  63.3900   7712127
# 2018-12-31  64.4000   7690183
#
# [1006 rows x 2 columns]

# %% [markdown]
# ### Resample()

# %%
#A common operation with time series data is resampling based on the time series index.

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %% [markdown]
# The rule parameter describes the frequency with which to apply the aggregation function (daily, monthly, yearly, etc.)
# It is passed in using an "offset alias" - refer to the table below

# %% [markdown]
#  TIME SERIES OFFSET ALIASES ALIAS	DESCRIPTION
#
# + B	business day frequency
# + C	custom business day frequency (experimental)
# + D	calendar day frequency
# + W	weekly frequency
# + M	month end frequency
# + SM	semi-month end frequency (15th and end of month)
# + BM	business month end frequency
# + CBM	custom business month end frequency
# + MS	month start frequency
# + SMS	semi-month start frequency (1st and 15th)
# + BMS	business month start frequency
# + CBMS	custom business month start frequency
# + Q	quarter end frequency
#
# ALIAS	DESCRIPTION
# + BQ	business quarter endfrequency
# + QS	quarter start frequency
# + BQS	business quarter start frequency
# + A	year end frequency
# + BA	business year end frequency
# + AS	year start frequency
# + BAS	business year start frequency
# + BH	business hour frequency
# + H	hourly frequency
# + T, min	minutely frequency
# + S	secondly frequency
# + L, ms	milliseconds
# + U, us	microseconds
# + N	nanoseconds

# %%
df
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548
# ...             ...       ...
# 2018-12-24  60.5600   6323252
# 2018-12-26  63.0800  16646238
# 2018-12-27  63.2000  11308081
# 2018-12-28  63.3900   7712127
# 2018-12-31  64.4000   7690183
#
# [1006 rows x 2 columns]

# %%
# Yearly Means
df.resample(rule='YE').mean() #A deprecated
# Out:
#                 Close        Volume
# Date
# 2015-12-31  50.078100  8.649190e+06
# 2016-12-31  53.891732  9.300633e+06
# 2017-12-31  55.457310  9.296078e+06
# 2018-12-31  56.870005  1.122883e+07

# %%
# Yearly Means
df.resample(rule='YE').max()
# Out:
#               Close    Volume
# Date
# 2015-12-31  59.8475  38107194
# 2016-12-31  58.0465  32820193
# 2017-12-31  62.4924  53454789
# 2018-12-31  68.3530  62091071

# %%
df.resample(rule='YE').max().index
# Out:
# DatetimeIndex(['2015-12-31', '2016-12-31', '2017-12-31', '2018-12-31'], dtype='datetime64[ns]', name='Date', freq='YE-DEC')

# %%
# Yearly Means
df.resample(rule='YE').min()
# Out:
#               Close   Volume
# Date
# 2015-12-31  36.9748  2215418
# 2016-12-31  49.4458  3228848
# 2017-12-31  51.2345  3479177
# 2018-12-31  47.9470  4843941

# %%
# Yearly Means
df.resample(rule='YE').std()
# Out:
#                Close        Volume
# Date
# 2015-12-31  6.076922  4.093368e+06
# 2016-12-31  1.958114  3.936798e+06
# 2017-12-31  2.415526  4.690972e+06
# 2018-12-31  4.678178  6.465358e+06

# %%
df.resample(rule='BM').mean().shape
# Out:
# <ipython-input-69-55a18c0bfdd6>:1: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   df.resample(rule='BM').mean().shape
# (48, 2)

# %% [markdown]
# ### Custom Resampling Functions

# %%
def first_day(entry):
    """
    Returns the first instance of the period, regardless of sampling rate.
    """
    if len(entry):  # handles the case of missing data
        return entry[0]

# %%
df.resample(rule='YE').apply(first_day)
# Out:
# <ipython-input-70-cd1ce69de5eb>:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return entry[0]
#               Close    Volume
# Date
# 2015-12-31  38.0061   6906098
# 2016-12-31  55.0780  13521544
# 2017-12-31  53.1100   7809307
# 2018-12-31  56.3243   7215978

# %%
## plotting
df['Close'].resample('YE').mean().plot.bar(title='Yearly Mean Closing Price for Starbucks');

# %%
title = 'Monthly Max Closing Price for Starbucks'
df['Close'].resample('ME').max().plot.bar(
                                    figsize=(16,6),
                                    title=title,
                                    color='red');
