# %% [markdown]
# ## From Scikit-learn to Arduino
#
# Machine learning on Arduino boards is it possible?
#
# Do you want to run the model you trained in Python into any C++ project, be it Arduino, STM32, ESP32?

# %% [markdown]
# ## Step1 load data
# To train a classifier, we need some data. If you're starting from zero and don't have already a preferred folder structure, I suggest you to create a folder that will hold the data you collect.
#
# Inside this folder, create a dedicated file (.csv) for each of the classes you want to classify, putting a sample on each line. If doing so, you can use the next function to load this data.

# %%
# !mkdir datafolder
# Out:
# mkdir: cannot create directory ‘datafolder’: File exists

# %%
# !wget https://frenzy86.s3.eu-west-2.amazonaws.com/python/sample_binarydata.csv -O /content/datafolder/sample_binarydata.csv
# Out:
# --2023-11-07 13:51:23--  https://frenzy86.s3.eu-west-2.amazonaws.com/python/sample_binarydata.csv
# Resolving frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)... 52.95.148.158, 52.95.150.142, 52.95.142.62, ...
# Connecting to frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)|52.95.148.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23777 (23K) [text/csv]
# Saving to: ‘/content/datafolder/sample_binarydata.csv’
#
# /content/datafolder 100%[===================>]  23.22K  --.-KB/s    in 0.09s
#
# 2023-11-07 13:51:23 (266 KB/s) - ‘/content/datafolder/sample_binarydata.csv’ saved [23777/23777]

# %%
import numpy as np

def load_data(file):
    data = np.loadtxt(file, dtype=float, delimiter=',')
    classmap = {
                0:'survived',
                1:'died',
                }
    return data, classmap

# %%
data = np.loadtxt('datafolder/sample_binarydata.csv', dtype=float, delimiter=',')
data
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %% [markdown]
# ## Step2 Train Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

def modeling(data):
    X, y = data[:, :-1], data[:, -1]
    k = 5
    k_best = SelectKBest(score_func=f_classif, k=k)
    k_best.fit(X, y)
    selected_feature_indices = k_best.get_support(indices=True)

    clf = RandomForestClassifier(20, max_depth=10, random_state=667)

    return clf.fit(X[:, selected_feature_indices], y)

# %% [markdown]
# ## Step3 Export to C
# Now you can convert the trained classifier to plain C code using the micromlgen package.

# %%
# !pip install micromlgen -q

# %%
from micromlgen import port

dataset, classmap = load_data('datafolder/sample_binarydata.csv')
classifier = modeling(dataset)
classmap
# Out:
# {0: 'survived', 1: 'died'}

# %%
## testing classifier prediction
#classifier.predict([[6.,148.,33.6,0.627,50.]])[0] ## class1.0
classifier.predict([[1., 85.,26.6,0.351,31.]])[0] ##  class0.0
# Out:
# 0.0

# %%
c_code = port(classifier, classmap=classmap)
print(c_code)
# Out:
# #pragma once
# #include <cstdarg>
# namespace Eloquent {
#     namespace ML {
#         namespace Port {
#             class RandomForest {
#                 public:
#                     /**
#                     * Predict class for features vector
#                     */
#                     int predict(float *x) {
#                         uint8_t votes[2] = { 0 };
#                         // tree #1
#                         if (x[1] <= 154.5) {
#                             if (x[4] <= 29.5) {
#                                 if (x[3] <= 0.6924999952316284) {
#                                     if (x[2] <= 56.599998474121094) {
#                                         if (x[1] <= 112.5) {
#                                             if (x[2] <= 30.899999618530273) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[1] <= 78.5) {
#                                                     if (x[0] <= 4.0) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[0] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     if (x[0] <= 1.5) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[3] <= 0.6615000069141388) {
#                                                             if (x[3] <= 0.19749999791383743) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             if (x[1] <= 96.5) {
#                                                                 votes[1] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#                                                     }
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[1] <= 113.5) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[2] <= 27.550000190734863) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[2] <= 28.5) {
#                                                         if (x[3] <= 0.31050001084804535) {
#                                                             if (x[2] <= 28.199999809265137) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         if (x[2] <= 42.25) {
#                                                             if (x[3] <= 0.1550000011920929) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             if (x[2] <= 43.70000076293945) {
#                                                                 votes[1] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[2] <= 32.650001525878906) {
#                                         if (x[3] <= 1.2430000305175781) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             if (x[1] <= 127.5) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 34.85000038146973) {
#                                             if (x[0] <= 1.5) {
#                                                 if (x[1] <= 101.0) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[1] <= 118.5) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[4] <= 24.0) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[3] <= 0.7560000121593475) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[2] <= 26.949999809265137) {
#                                     if (x[3] <= 0.27650000154972076) {
#                                         if (x[4] <= 31.0) {
#                                             if (x[2] <= 12.800000190734863) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[3] <= 0.22049999982118607) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[1] <= 123.5) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[4] <= 55.5) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[0] += 1;
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[1] <= 99.5) {
#                                         if (x[3] <= 0.6685000061988831) {
#                                             if (x[0] <= 10.5) {
#                                                 if (x[1] <= 96.0) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[1] <= 98.0) {
#                                                         if (x[2] <= 36.849998474121094) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[0] += 1;
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[0] <= 12.5) {
#                                                     if (x[1] <= 86.0) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[0] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[2] <= 41.20000076293945) {
#                                                 if (x[1] <= 92.0) {
#                                                     votes[1] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 0.25300000607967377) {
#                                             if (x[2] <= 47.5) {
#                                                 if (x[2] <= 37.25) {
#                                                     if (x[1] <= 110.5) {
#                                                         if (x[4] <= 36.5) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         if (x[1] <= 123.5) {
#                                                             if (x[4] <= 31.5) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             if (x[2] <= 32.45000076293945) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     if (x[4] <= 43.5) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[3] <= 0.21449999511241913) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[3] <= 0.26099999248981476) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[3] <= 0.26749999821186066) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[2] <= 42.80000114440918) {
#                                                         if (x[2] <= 39.35000038146973) {
#                                                             if (x[2] <= 27.34999942779541) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         if (x[2] <= 46.44999885559082) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             if (x[0] <= 0.5) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[3] <= 0.2094999998807907) {
#                                 if (x[4] <= 59.5) {
#                                     if (x[4] <= 39.0) {
#                                         if (x[3] <= 0.1665000021457672) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             if (x[2] <= 34.19999885559082) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[0] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[1] <= 188.0) {
#                                     if (x[4] <= 63.0) {
#                                         if (x[2] <= 23.09999942779541) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             if (x[1] <= 182.0) {
#                                                 if (x[3] <= 0.2705000042915344) {
#                                                     if (x[0] <= 1.0) {
#                                                         if (x[2] <= 45.60000038146973) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[2] <= 38.60000038146973) {
#                                                     votes[1] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[3] <= 1.2475000023841858) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[0] += 1;
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 162.0) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[1] <= 195.0) {
#                                         if (x[2] <= 29.850000381469727) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#                             }
#                         }
#
#                         // tree #2
#                         if (x[2] <= 26.34999942779541) {
#                             if (x[1] <= 153.5) {
#                                 if (x[1] <= 124.5) {
#                                     if (x[0] <= 9.5) {
#                                         if (x[1] <= 106.5) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             if (x[1] <= 107.5) {
#                                                 if (x[4] <= 28.5) {
#                                                     votes[1] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[4] <= 30.5) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 2.5) {
#                                         votes[0] += 1;
#                                     }
#
#                                     else {
#                                         if (x[0] <= 4.5) {
#                                             if (x[4] <= 48.5) {
#                                                 if (x[1] <= 144.5) {
#                                                     votes[1] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[1] <= 125.5) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[0] <= 3.5) {
#                                     if (x[4] <= 28.5) {
#                                         votes[0] += 1;
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[1] <= 188.5) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         if (x[2] <= 26.0) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[1] <= 134.5) {
#                                 if (x[3] <= 0.6504999995231628) {
#                                     if (x[4] <= 28.5) {
#                                         if (x[2] <= 32.45000076293945) {
#                                             if (x[2] <= 32.25) {
#                                                 if (x[0] <= 7.0) {
#                                                     if (x[2] <= 30.949999809265137) {
#                                                         if (x[4] <= 27.5) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         if (x[0] <= 2.5) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[4] <= 22.5) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[3] <= 0.5105000138282776) {
#                                                 if (x[1] <= 95.5) {
#                                                     if (x[2] <= 37.150001525878906) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[1] <= 94.5) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[3] <= 0.5439999997615814) {
#                                                     if (x[1] <= 118.0) {
#                                                         if (x[2] <= 34.0) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             if (x[0] <= 3.0) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[0] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 34.64999961853027) {
#                                             if (x[1] <= 106.5) {
#                                                 if (x[0] <= 5.5) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[2] <= 29.75) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[4] <= 40.0) {
#                                                             if (x[4] <= 35.5) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[3] <= 0.42100000381469727) {
#                                                     if (x[2] <= 26.899999618530273) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[1] <= 127.0) {
#                                                             if (x[4] <= 60.0) {
#                                                                 votes[1] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             if (x[0] <= 4.0) {
#                                                                 votes[1] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     if (x[0] <= 2.0) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[3] <= 0.5609999895095825) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[2] <= 39.45000076293945) {
#                                                 if (x[0] <= 7.5) {
#                                                     if (x[3] <= 0.33400000631809235) {
#                                                         if (x[4] <= 40.5) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             if (x[1] <= 114.5) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[3] <= 0.28950001299381256) {
#                                                     if (x[0] <= 7.5) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[4] <= 43.5) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 7.5) {
#                                         if (x[4] <= 36.5) {
#                                             if (x[3] <= 0.68299999833107) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[4] <= 33.5) {
#                                                     if (x[2] <= 30.449999809265137) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[4] <= 24.5) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             if (x[1] <= 114.5) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[2] <= 32.89999961853027) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[2] <= 34.85000038146973) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[3] <= 0.7114999890327454) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[0] <= 2.5) {
#                                                             if (x[2] <= 37.70000076293945) {
#                                                                 votes[1] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[1] <= 82.0) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[1] <= 166.0) {
#                                     if (x[4] <= 61.5) {
#                                         if (x[2] <= 41.64999961853027) {
#                                             if (x[2] <= 37.25) {
#                                                 if (x[2] <= 29.850000381469727) {
#                                                     if (x[2] <= 27.550000190734863) {
#                                                         if (x[4] <= 34.0) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             if (x[2] <= 27.049999237060547) {
#                                                                 votes[1] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         if (x[2] <= 28.350000381469727) {
#                                                             if (x[3] <= 0.2905000075697899) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     if (x[3] <= 0.4424999952316284) {
#                                                         if (x[0] <= 1.5) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             if (x[4] <= 24.5) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         if (x[1] <= 150.5) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             if (x[2] <= 34.89999961853027) {
#                                                                 votes[1] += 1;
#                                                             }
# ...
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[3] <= 0.1705000028014183) {
#                                                     if (x[4] <= 33.0) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[0] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= 3.5) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             if (x[1] <= 82.0) {
#                                                 if (x[2] <= 37.14999961853027) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[3] <= 0.3945000022649765) {
#                                         if (x[3] <= 0.3869999945163727) {
#                                             if (x[1] <= 136.5) {
#                                                 if (x[4] <= 47.5) {
#                                                     if (x[2] <= 34.44999885559082) {
#                                                         if (x[4] <= 36.5) {
#                                                             if (x[1] <= 123.0) {
#                                                                 votes[1] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             if (x[4] <= 38.5) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         if (x[2] <= 36.849998474121094) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             if (x[3] <= 0.31449998915195465) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     if (x[0] <= 2.5) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[3] <= 0.13699999824166298) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[0] <= 5.5) {
#                                                     if (x[3] <= 0.2775000035762787) {
#                                                         if (x[4] <= 58.0) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             if (x[1] <= 151.5) {
#                                                                 votes[1] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         if (x[3] <= 0.3425000011920929) {
#                                                             if (x[1] <= 147.5) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     if (x[1] <= 141.5) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[0] <= 8.5) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             if (x[0] <= 10.5) {
#                                                                 votes[1] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#                                                     }
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[3] <= 1.3949999809265137) {
#                                             if (x[2] <= 38.60000038146973) {
#                                                 if (x[4] <= 42.5) {
#                                                     if (x[1] <= 127.0) {
#                                                         if (x[0] <= 2.5) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             if (x[4] <= 34.5) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         if (x[2] <= 34.5) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             if (x[1] <= 159.0) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[0] <= 8.0) {
#                                                     if (x[1] <= 131.5) {
#                                                         if (x[2] <= 40.89999961853027) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             if (x[3] <= 0.6980000138282776) {
#                                                                 votes[1] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         if (x[1] <= 180.0) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     if (x[2] <= 40.89999961853027) {
#                                                         if (x[3] <= 0.8510000109672546) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[4] <= 33.5) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         // return argmax of votes
#                         uint8_t classIdx = 0;
#                         float maxVotes = votes[0];
#
#                         for (uint8_t i = 1; i < 2; i++) {
#                             if (votes[i] > maxVotes) {
#                                 classIdx = i;
#                                 maxVotes = votes[i];
#                             }
#                         }
#
#                         return classIdx;
#                     }
#
#                     /**
#                     * Predict readable class name
#                     */
#                     const char* predictLabel(float *x) {
#                         return idxToLabel(predict(x));
#                     }
#
#                     /**
#                     * Convert class idx to readable name
#                     */
#                     const char* idxToLabel(uint8_t classIdx) {
#                         switch (classIdx) {
#                             case 0:
#                             return "survived";
#                             case 1:
#                             return "died";
#                             default:
#                             return "Houston we have a problem";
#                         }
#                     }
#
#                 protected:
#                 };
#             }
#         }
#     }

# %%
## write model into model.h
file_path = "model.h"

with open(file_path, 'w') as file:
    file.write(c_code)

# %% [markdown]
# ## Step4 Load model into Arduino

# %%
# // put the code you got in Step 3 into this file
# #include "model.h"

# // this class will be different if you used another type of classifier, just check the model.h file
# Eloquent::ML::Port::RandomForest classifier;

# void classify() {
#     float x_sample[] = { /* fill this vector with sample values */ };

#     Serial.print("Predicted class: ");
#     Serial.println(classifier.predictLabel(x_sample));
# }
